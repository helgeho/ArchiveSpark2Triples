// %% [markdown]
// This notebook requires FEL4ArchiveSpark: https://github.com/helgeho/FEL4ArchiveSpark

// %%
import de.l3s.archivespark._
import de.l3s.archivespark.implicits._
import de.l3s.archivespark.specific.warc._
import de.l3s.archivespark.specific.warc.specs._
import de.l3s.archivespark.specific.warc.implicits._
import de.l3s.archivespark.enrich._
import de.l3s.archivespark.enrich.functions._
import de.l3s.archivespark.enrich.dataloads._
import de.l3s.archivespark.enrichfunctions.fel._
import de.l3s.archivespark2triples._
import org.apache.hadoop.io.compress.GzipCodec

// %%
sc.setCheckpointDir("spark_checkpoint")

// %% [markdown]
// # Load the FEL model file

// %%
val modelFile = "english-nov15.hash"
sc.addFile("hdfs:///user/holzmann/" + modelFile)

// %% [markdown]
// # Load the web archive collection (filter duplicates and very big records)

// %%
ArchiveSpark2Triples.versionUrl = r => s"https://wayback.archive-it.org/2950/${r.timestamp}/${r.originalUrl}"

// %%
val collection = "ArchiveIt-Collection-2950"
val cdxPath = s"/data/archiveit/$collection/cdx/*.cdx.gz"
val warcPath = s"/data/archiveit/$collection/warc"
val raw = ArchiveSpark.load(sc, WarcCdxHdfsSpec(cdxPath, warcPath))

// %%
val records = raw.distinctValue(_.get)((a, b) => a).filter(_.compressedSize < 1024 * 100).cache // 100 kb

// %%
records.peekJson
// Out:
// {
//   "record":{
//     "redirectUrl":"-",
//     "timestamp":"20120515050246",
//     "digest":"QMKCJGWCZI2GOTC6W7TQ5YTMY2YRMWWV",
//     "originalUrl":"http://www.occupyslc.org/login/return_url/64-L2dyb3VwLzIz",
//     "surtUrl":"org,occupyslc)/login/return_url/64-l2dyb3vwlziz",
//     "mime":"text/html",
//     "compressedSize":4499,
//     "meta":"-",
//     "status":200
//   }
// }

// %% [markdown]
// # Select successful responses of type HTML and detect duplicates

// %%
val responses = records.filter(r => r.status == 200 && r.mime == "text/html")

// %%
val earliestDigests = responses.map(r => ((r.surtUrl, r.digest), r)).reduceByKey{(r1, r2) =>
    if (r1.time < r2.time) r1 else r2
}

// %%
earliestDigests.count
// Out:
// 7750123

// %%
val duplicates = records.map(r => ((r.surtUrl, r.digest), r)).join(earliestDigests).map{case (_, records) => records}.filter{case (r1, r2) => r1.time != r2.time}

// %%
duplicates.count
// Out:
// 1344450

// %% [markdown]
// # Generate *ArchivedDocument* triples representing distinct webpages

// %%
val versions = earliestDigests.map{case (_, r) => r}.union(duplicates.map{case (r1, r2) => r1})

// %%
versions.count
// Out:
// 9094573

// %%
val documentTriples = ArchiveSpark2Triples.generateDocs(versions)

// %%
documentTriples.count
// Out:
// 3036326

// %%
println(documentTriples.peek)
// Out:
// <http://groups.google.com/group/LSX-Occupy-Environment-Group/tree/browse_frm/thread/25b17e5476a9828f/56ecd5b1ac6e6da0?rnum=1&_done=%2Fgroup%2FLSX-Occupy-Environment-Group%2Fbrowse_frm%2Fthread%2F25b17e5476a9828f%2F4fa88fade9b35d85%3Fshow_docid%3D4fa88fade9b35d85%26fwc%3D2%26> rdf:type owa:ArchivedDocument ;
//     owa:numOfCaptures    "1"^^xsd:integer ;
//     owa:firstCapture     "2012-02-10T08:46:47"^^xsd:dateTime ;
//     owa:lastCapture      "2012-02-10T08:46:47"^^xsd:dateTime ;
//     dc:hasVersion        <https://wayback.archive-it.org/2950/20120210084647/http://groups.google.com/group/LSX-Occupy-Environment-Group/tree/browse_frm/thread/25b17e5476a9828f/56ecd5b1ac6e6da0?rnum=1&_done=%2Fgroup%2FLSX-Occupy-Environment-Group%2Fbrowse_frm%2Fthread%2F25b17e5476a9828f%2F4fa88fade9b35d85%3Fshow_docid%3D4fa88fade9b35d85%26fwc%3D2%26> .

// %% [markdown]
// # Create "*sameAs* triples" from duplicates

// %%
val sameAsTriples = ArchiveSpark2Triples.generateSameAsVersions(duplicates)

// %%
println(sameAsTriples.peek)
// Out:
// <https://wayback.archive-it.org/2950/20120105062548/http://www.livestream.com/forum/showpost.php?p=18958&postcount=9> rdf:type owa:VersionedDocument ;
//     dc:date              "2012-01-05T06:25:48"^^xsd:dateTime ;
//     owl:sameAs           <https://wayback.archive-it.org/2950/20111229064632/http://www.livestream.com/forum/showpost.php?p=18958&postcount=9> .

// %% [markdown]
// # Generate *VersionedDocument* triples with title and entities

// %%
val repartitioned = earliestDigests.map{case (_, r) => r}.repartition(5000)

// %%
val title = HtmlText.of(Html.first("title"))
val responsesWithTitles = repartitioned.enrich(title)

// %%
val fel = FELwithTimeOut(scoreThreshold = -4, modelFile = modelFile).on(HtmlText)
val responsesWithEntities = responsesWithTitles.enrich(fel)

// %%
responsesWithEntities.peekJson
// Out:
// {
//   "record":{
//     "redirectUrl":"-",
//     "timestamp":"20120212211640",
//     "digest":"FGHAMAB45Z57X5HTBRHZG24Q5BMFQIIL",
//     "originalUrl":"http://occupyannecy.over-blog.com/m/recherche/datatable/ga20795271._setAccount",
//     "surtUrl":"com,over-blog,occupyannecy)/m/recherche/datatable/ga20795271._setaccount",
//     "mime":"text/html",
//     "compressedSize":4202,
//     "meta":"-",
//     "status":200
//   },
//   "payload":{
//     "string":{
//       "html":{
//         "title":{
//           "text":"datatable/ga20795271._setaccount sur OverBlog - Datation moléculaire des espèces : des dizaines de millions d'années d'erreur ?"
//         },
//         "body":{
//           "text":{
//             "entities":[
//               {
//                 "span":"cmd",
//                 "endOffset":13,
//                 "score"...

// %%
val versionTriples = ArchiveSpark2Triples.generateVersionsMapped(responsesWithEntities) {(record, uid, doc) =>
    val recordTitle = record.value(title).getOrElse("")
    val recordEntities = record.value(fel).getOrElse(Seq.empty)
    doc.appendTriples("dc:title", s"""\"$recordTitle\"""").appendChildren("schema:mentions", {
        recordEntities.zipWithIndex.map{case (entity, i) => TripleDoc(
            s"_:e$uid-$i",
            "oae:Entity",
            Seq(
                "oae:confidence" -> Seq(s""""${entity.score}"^^xsd:double"""),
                "oae:detectedAs" -> Seq(s"""\"${entity.span}\""""),
                "oae:position" -> Seq(s""""${entity.startOffset}"^^xsd:integer"""),
                "oae:hasMatchedURI" -> Seq(s"<http://dbpedia.org/resource/${entity.annotation}>")
            )
        )}
    })
}

// %%
println(versionTriples.peek)
// Out:
// <https://wayback.archive-it.org/2950/20120104203525/http://occupyfairbanks.org/galleries/sites/all/modules/comment_notify/sites/all/modules/panels/css/modules/system/system.menus.css> rdf:type owa:VersionedDocument ;
//     dc:date              "2012-01-04T20:35:25"^^xsd:dateTime ;
//     dc:format            "text/html" ;
//     dc:title             "Galleries | Occupy Fairbanks" ;
//     schema:mentions      _:e0-0,
//                          _:e0-1,
//                          _:e0-2,
//                          _:e0-3,
//                          _:e0-4,
//                          _:e0-5,
//                          _:e0-6,
//                          _:e0-7,
//                          _:e0-8,
//                          _:e0-9,
//                          _:e0-10,
//                          _:e0-11,
//                          _:e0-12,
//                          _:e0-13,
//                          _:e0-14,
//                          _:e0-15,
//                          _:e0-16,
//                          _:e0-17,
//                          _:e0-18,
//                          _:e0-19,
//                          _:e0-20,
//                          _:e0-21,
//                          _:e0-22,
//                          _:e0-23,
//                          _:e0-24,
//                          _:e0-25,
//                          _:e0-26,
//                          _:e0-27,
//                          _:e0-28,
//                          _:e0-29,
//                          _:e0-30,
//                          _:e0-31,
//                          _:e0-32,
//                          _:e0-33,
//                          _:e0-34,
//                          _:e0-35,
//                          _:e0-36,
//                          _:e0-37,
//                          _:e0-38,
//                          _:e0-39,
//                          _:e0-40,
//                          _:e0-41,
//                          _:e0-42,
//                          _:e0-43,
//                          _:e0-44,
//                          _:e0-45,
//                          _:e0-46,
//                          _:e0-47,
//                          _:e0-48,
//                          _:e0-49,
//                          _:e0-50,
//                          _:e0-51,
//                          _:e0-52,
//                          _:e0-53,
//                          _:e0-54,
//                          _:e0-55,
//                          _:e0-56,
//                          _:e0-57,
//                          _:e0-58,
//                          _:e0-59,
//                          _:e0-60,
//                          _:e0-61,
//                          _:e0-62,
//                          _:e0-63,
//                          _:e0-64,
//                          _:e0-65,
//                          _:e0-66,
//                          _:e0-67,
//                          _:e0-68,
//                          _:e0-69,
//                          _:e0-70,
//                          _:e0-71,
//                          _:e0-72,
//                          _:e0-73,
//                          _:e0-74,
//                          _:e0-75,
//                          _:e0-76,
//                          _:e0-77,
//                          _:e0-78,
//                          _:e0-79,
//                          _:e0-80,
//                          _:e0-81,
//                          _:e0-82,
//                          _:e0-83,
//                          _:e0-84,
//                          _:e0-85,
//                          _:e0-86,
//                          _:e0-87,
//                          _:e0-88,
//                          _:e0-89,
//                          _:e0-90,
//                          _:e0-91,
//                          _:e0-92,
//                          _:e0-93,
//                          _:e0-94,
//                          _:e0-95,
//                          _:e0-96,
//                          _:e0-97,
//                          _:e0-98,
//                          _:e0-99,
//                          _:e0-100,
//                          _:e0-101,
//                          _:e0-102,
//                          _:e0-103,
//                          _:e0-104,
//                          _:e0-105,
//                          _:e0-106,
//                          _:e0-107,
//                          _:e0-108,
//                          _:e0-109,
//                          _:e0-110,
//                          _:e0-111,
//                          _:e0-112,
//                          _:e0-113,
//                          _:e0-114,
//                          _:e0-115,
//                          _:e0-116,
//                          _:e0-117,
//                          _:e0-118,
//                          _:e0-119,
//                          _:e0-120,
//                          _:e0-121,
//                          _:e0-122,
//                          _:e0-123,
//                          _:e0-124,
//                          _:e0-125,
//                          _:e0-126,
//                          _:e0-127,
//                          _:e0-128,
//                          _:e0-129,
//                          _:e0-130,
//                          _:e0-131,
//                          _:e0-132,
//                          _:e0-133,
//                          _:e0-134,
//                          _:e0-135,
//                          _:e0-136,
//                          _:e0-137,
//                          _:e0-138,
//                          _:e0-139,
//                          _:e0-140,
//                          _:e0-141,
//                          _:e0-142,
//                          _:e0-143,
//                          _:e0-144,
//                          _:e0-145,
//                          _:e0-146,
//                          _:e0-147,
//                          _:e0-148,
//                          _:e0-149,
//                          _:e0-150,
//                          _:e0-151,
//                          _:e0-152,
//                          _:e0-153,
//                          _:e0-154,
//                          _:e0-155,
//                          _:e0-156,
//                          _:e0-157,
//                          _:e0-158,
//                          _:e0-159,
//                          _:e0-160,
//                          _:e0-161,
//                          _:e0-162,
//                          _:e0-163,
//                          _:e0-164,
//                          _:e0-165,
//                          _:e0-166,
//                          _:e0-167,
//                          _:e0-168,
//                          _:e0-169,
//                          _:e0-170,
//                          _:e0-171,
//                          _:e0-172,
//                          _:e0-173,
//                          _:e0-174,
//                          _:e0-175,
//                          _:e0-176,
//                          _:e0-177,
//                          _:e0-178,
//                          _:e0-179,
//                          _:e0-180,
//                          _:e0-181,
//                          _:e0-182,
//                          _:e0-183,
//                          _:e0-184,
//                          _:e0-185,
//                          _:e0-186,
//                          _:e0-187,
//                          _:e0-188,
//                          _:e0-189,
//                          _:e0-190,
//                          _:e0-191,
//                          _:e0-192,
//                          _:e0-193,
//                          _:e0-194,
//                          _:e0-195,
//                          _:e0-196,
//                          _:e0-197,
//                          _:e0-198,
//                          _:e0-199,
//                          _:e0-200,
//                          _:e0-201,
//                          _:e0-202,
//                          _:e0-203,
//                          _:e0-204,
//                          _:e0-205,
//                          _:e0-206,
//                          _:e0-207,
//                          _:e0-208,
//                          _:e0-209,
//                          _:e0-210,
//                          _:e0-211,
//                          _:e0-212,
//                          _:e0-213,
//                          _:e0-214,
//                          _:e0-215,
//                          _:e0-216,
//                          _:e0-217,
//                          _:e0-218,
//                          _:e0-219,
//                          _:e0-220,
//                          _:e0-221,
//                          _:e0-222,
//                          _:e0-223,
//                          _:e0-224,
//                          _:e0-225,
//                          _:e0-226,
//                          _:e0-227,
//                          _:e0-228,
//                          _:e0-229,
//                          _:e0-230,
//                          _:e0-231,
//                          _:e0-232,
//                          _:e0-233,
//                          _:e0-234,
//                          _:e0-235,
//                          _:e0-236,
//                          _:e0-237,
//                          _:e0-238,
//                          _:e0-239,
//                          _:e0-240,
//                          _:e0-241,
//                          _:e0-242,
//                          _:e0-243,
//                          _:e0-244,
//                          _:e0-245,
//                          _:e0-246,
//                          _:e0-247,
//                          _:e0-248,
//                          _:e0-249,
//                          _:e0-250,
//                          _:e0-251,
//                          _:e0-252,
//                          _:e0-253,
//                          _:e0-254,
//                          _:e0-255,
//                          _:e0-256,
//                          _:e0-257,
//                          _:e0-258,
//                          _:e0-259 .
//
//     _:e0-0 rdf:type oae:Entity ;
//         oae:confidence       "-0.8146953442188489"^^xsd:double ;
//         oae:detectedAs       "bradley manning" ;
//         oae:position         "896"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Chelsea_Manning> .
//
//     _:e0-1 rdf:type oae:Entity ;
//         oae:confidence       "-1.1175189247062232"^^xsd:double ;
//         oae:detectedAs       "food not bombs" ;
//         oae:position         "528"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Food_Not_Bombs> .
//
//     _:e0-2 rdf:type oae:Entity ;
//         oae:confidence       "-1.281067090742663"^^xsd:double ;
//         oae:detectedAs       "fairbanks international airport" ;
//         oae:position         "325"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Fairbanks_International_Airport> .
//
//     _:e0-3 rdf:type oae:Entity ;
//         oae:confidence       "-1.6726053824799108"^^xsd:double ;
//         oae:detectedAs       "candlelight vigil" ;
//         oae:position         "867"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Candlelight_vigil> .
//
//     _:e0-4 rdf:type oae:Entity ;
//         oae:confidence       "-1.7552143094338724"^^xsd:double ;
//         oae:detectedAs       "calendar" ;
//         oae:position         "53"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Calendar> .
//
//     _:e0-5 rdf:type oae:Entity ;
//         oae:confidence       "-1.951929661513037"^^xsd:double ;
//         oae:detectedAs       "weather" ;
//         oae:position         "301"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Weather_Channel> .
//
//     _:e0-6 rdf:type oae:Entity ;
//         oae:confidence       "-2.1887318833014553"^^xsd:double ;
//         oae:detectedAs       "benefit concert" ;
//         oae:position         "1028"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Benefit_concert> .
//
//     _:e0-7 rdf:type oae:Entity ;
//         oae:confidence       "-2.2151475593537837"^^xsd:double ;
//         oae:detectedAs       "paradigms" ;
//         oae:position         "814"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Paradigm> .
//
//     _:e0-8 rdf:type oae:Entity ;
//         oae:confidence       "-2.312475265649996"^^xsd:double ;
//         oae:detectedAs       "facebook connect" ;
//         oae:position         "151"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook_Platform> .
//
//     _:e0-9 rdf:type oae:Entity ;
//         oae:confidence       "-2.3389817931492387"^^xsd:double ;
//         oae:detectedAs       "overcast" ;
//         oae:position         "357"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Overcast> .
//
//     _:e0-10 rdf:type oae:Entity ;
//         oae:confidence       "-2.7627953732910795"^^xsd:double ;
//         oae:detectedAs       "round table" ;
//         oae:position         "1077"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Round_Table> .
//
//     _:e0-11 rdf:type oae:Entity ;
//         oae:confidence       "-2.8276094336573405"^^xsd:double ;
//         oae:detectedAs       "anchorage port" ;
//         oae:position         "952"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Port_of_Anchorage> .
//
//     _:e0-12 rdf:type oae:Entity ;
//         oae:confidence       "-2.8831279166050616"^^xsd:double ;
//         oae:detectedAs       "you are here" ;
//         oae:position         "500"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Are_You_Here> .
//
//     _:e0-13 rdf:type oae:Entity ;
//         oae:confidence       "-2.9759648525325217"^^xsd:double ;
//         oae:detectedAs       "username" ;
//         oae:position         "221"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/User_%28computing%29> .
//
//     _:e0-14 rdf:type oae:Entity ;
//         oae:confidence       "-2.9973775053805642"^^xsd:double ;
//         oae:detectedAs       "sunset" ;
//         oae:position         "447"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Sunset> .
//
//     _:e0-15 rdf:type oae:Entity ;
//         oae:confidence       "-3.0002856128197894"^^xsd:double ;
//         oae:detectedAs       "alaska" ;
//         oae:position         "835"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Alaska> .
//
//     _:e0-16 rdf:type oae:Entity ;
//         oae:confidence       "-3.0637531770005975"^^xsd:double ;
//         oae:detectedAs       "cardboard" ;
//         oae:position         "592"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cardboard> .
//
//     _:e0-17 rdf:type oae:Entity ;
//         oae:confidence       "-3.0895861898410284"^^xsd:double ;
//         oae:detectedAs       "sunrise" ;
//         oae:position         "430"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Sunrise> .
//
//     _:e0-18 rdf:type oae:Entity ;
//         oae:confidence       "-3.2368205538525885"^^xsd:double ;
//         oae:detectedAs       "8" ;
//         oae:position         "1057"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/8> .
//
//     _:e0-19 rdf:type oae:Entity ;
//         oae:confidence       "-3.293898228478974"^^xsd:double ;
//         oae:detectedAs       "password" ;
//         oae:position         "284"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Password> .
//
//     _:e0-20 rdf:type oae:Entity ;
//         oae:confidence       "-3.293898228478974"^^xsd:double ;
//         oae:detectedAs       "password" ;
//         oae:position         "242"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Password> .
//
//     _:e0-21 rdf:type oae:Entity ;
//         oae:confidence       "-3.3972778598240545"^^xsd:double ;
//         oae:detectedAs       "e mail" ;
//         oae:position         "233"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Email> .
//
//     _:e0-22 rdf:type oae:Entity ;
//         oae:confidence       "-3.4136198734177605"^^xsd:double ;
//         oae:detectedAs       "12 16 2011" ;
//         oae:position         "912"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/December_16> .
//
//     _:e0-23 rdf:type oae:Entity ;
//         oae:confidence       "-3.419973347418191"^^xsd:double ;
//         oae:detectedAs       "anchorage" ;
//         oae:position         "1000"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Anchorage%2C_Alaska> .
//
//     _:e0-24 rdf:type oae:Entity ;
//         oae:confidence       "-3.419973347418191"^^xsd:double ;
//         oae:detectedAs       "anchorage" ;
//         oae:position         "933"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Anchorage%2C_Alaska> .
//
//     _:e0-25 rdf:type oae:Entity ;
//         oae:confidence       "-3.5677122185883583"^^xsd:double ;
//         oae:detectedAs       "visibility" ;
//         oae:position         "413"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Visibility> .
//
//     _:e0-26 rdf:type oae:Entity ;
//         oae:confidence       "-3.7308926594478424"^^xsd:double ;
//         oae:detectedAs       "open carry" ;
//         oae:position         "1089"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Open_carry_in_the_United_States> .
//
//     _:e0-27 rdf:type oae:Entity ;
//         oae:confidence       "-3.8155986716414425"^^xsd:double ;
//         oae:detectedAs       "fairbanks" ;
//         oae:position         "1065"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Fairbanks%2C_Alaska> .
//
//     _:e0-28 rdf:type oae:Entity ;
//         oae:confidence       "-3.8155986716414425"^^xsd:double ;
//         oae:detectedAs       "fairbanks" ;
//         oae:position         "561"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Fairbanks%2C_Alaska> .
//
//     _:e0-29 rdf:type oae:Entity ;
//         oae:confidence       "-3.8155986716414425"^^xsd:double ;
//         oae:detectedAs       "fairbanks" ;
//         oae:position         "33"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Fairbanks%2C_Alaska> .
//
//     _:e0-30 rdf:type oae:Entity ;
//         oae:confidence       "-3.8166145805714593"^^xsd:double ;
//         oae:detectedAs       "submit" ;
//         oae:position         "705"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Submit> .
//
//     _:e0-31 rdf:type oae:Entity ;
//         oae:confidence       "-3.8166145805714593"^^xsd:double ;
//         oae:detectedAs       "submit" ;
//         oae:position         "578"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Submit> .
//
//     _:e0-32 rdf:type oae:Entity ;
//         oae:confidence       "-3.872465639810725"^^xsd:double ;
//         oae:detectedAs       "forums" ;
//         oae:position         "62"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Internet_forum> .
//
//     _:e0-33 rdf:type oae:Entity ;
//         oae:confidence       "-3.9198663999133805"^^xsd:double ;
//         oae:detectedAs       "chili" ;
//         oae:position         "1100"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Chili_con_carne> .
//
//     _:e0-34 rdf:type oae:Entity ;
//         oae:confidence       "-3.9327337830681075"^^xsd:double ;
//         oae:detectedAs       "noon" ;
//         oae:position         "1120"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Noon> .
//
//     _:e0-35 rdf:type oae:Entity ;
//         oae:confidence       "-3.93991420636616"^^xsd:double ;
//         oae:detectedAs       "pork" ;
//         oae:position         "967"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Pork> .
//
//     _:e0-36 rdf:type oae:Entity ;
//         oae:confidence       "-3.972867704170017"^^xsd:double ;
//         oae:detectedAs       "6" ;
//         oae:position         "425"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/6> .
//
//     _:e0-37 rdf:type oae:Entity ;
//         oae:confidence       "-3.975021178342929"^^xsd:double ;
//         oae:detectedAs       "3" ;
//         oae:position         "455"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/3> .
//
//     _:e0-38 rdf:type oae:Entity ;
//         oae:confidence       "-3.9808048991095917"^^xsd:double ;
//         oae:detectedAs       "mist" ;
//         oae:position         "379"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Mist> .
//
//     _:e0-39 rdf:type oae:Entity ;
//         oae:confidence       "-3.9836973130387014"^^xsd:double ;
//         oae:detectedAs       "literature" ;
//         oae:position         "109"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Literature> .
//
//     _:e0-40 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "1213"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-41 rdf:type oae:Entity ;
//         oae:confidence       "-2.376936411919932"^^xsd:double ;
//         oae:detectedAs       "the session" ;
//         oae:position         "1313"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Sessions_%28film%29> .
//
//     _:e0-42 rdf:type oae:Entity ;
//         oae:confidence       "-2.884427567041857"^^xsd:double ;
//         oae:detectedAs       "init" ;
//         oae:position         "1216"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Init> .
//
//     _:e0-43 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "1509"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-44 rdf:type oae:Entity ;
//         oae:confidence       "-1.1659696852246162"^^xsd:double ;
//         oae:detectedAs       "oauth" ;
//         oae:position         "1436"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/OAuth> .
//
//     _:e0-45 rdf:type oae:Entity ;
//         oae:confidence       "-2.7150790856770235"^^xsd:double ;
//         oae:detectedAs       "html" ;
//         oae:position         "1429"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTML> .
//
//     _:e0-46 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "1585"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-47 rdf:type oae:Entity ;
//         oae:confidence       "-3.738800761032081"^^xsd:double ;
//         oae:detectedAs       "logout" ;
//         oae:position         "1610"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Login> .
//
//     _:e0-48 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "1696"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-49 rdf:type oae:Entity ;
//         oae:confidence       "-2.884427567041857"^^xsd:double ;
//         oae:detectedAs       "init" ;
//         oae:position         "1699"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Init> .
//
//     _:e0-50 rdf:type oae:Entity ;
//         oae:confidence       "-3.934500644104404"^^xsd:double ;
//         oae:detectedAs       "var" ;
//         oae:position         "1724"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Value_at_risk> .
//
//     _:e0-51 rdf:type oae:Entity ;
//         oae:confidence       "-3.1111830032248085"^^xsd:double ;
//         oae:detectedAs       "src" ;
//         oae:position         "1768"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Proto-oncogene_tyrosine-protein_kinase_Src> .
//
//     _:e0-52 rdf:type oae:Entity ;
//         oae:confidence       "-3.55185790536142"^^xsd:double ;
//         oae:detectedAs       "connect" ;
//         oae:position         "1806"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cone_beam_computed_tomography> .
//
//     _:e0-53 rdf:type oae:Entity ;
//         oae:confidence       "-3.938161261400002"^^xsd:double ;
//         oae:detectedAs       "protocol" ;
//         oae:position         "1792"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Protocol> .
//
//     _:e0-54 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "1814"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-55 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "1837"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-56 rdf:type oae:Entity ;
//         oae:confidence       "-2.8257335594337816"^^xsd:double ;
//         oae:detectedAs       "async" ;
//         oae:position         "1844"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Asynchronous_communication> .
//
//     _:e0-57 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "1883"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-58 rdf:type oae:Entity ;
//         oae:confidence       "-3.1111830032248085"^^xsd:double ;
//         oae:detectedAs       "src" ;
//         oae:position         "1964"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Proto-oncogene_tyrosine-protein_kinase_Src> .
//
//     _:e0-59 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "2028"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-60 rdf:type oae:Entity ;
//         oae:confidence       "-3.934500644104404"^^xsd:double ;
//         oae:detectedAs       "var" ;
//         oae:position         "2063"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Value_at_risk> .
//
//     _:e0-61 rdf:type oae:Entity ;
//         oae:confidence       "-2.768340736226127"^^xsd:double ;
//         oae:detectedAs       "ua" ;
//         oae:position         "2112"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/.ua> .
//
//     _:e0-62 rdf:type oae:Entity ;
//         oae:confidence       "-2.9886372054796735"^^xsd:double ;
//         oae:detectedAs       "push" ;
//         oae:position         "2090"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Push_%282009_film%29> .
//
//     _:e0-63 rdf:type oae:Entity ;
//         oae:confidence       "-2.9886372054796735"^^xsd:double ;
//         oae:detectedAs       "push" ;
//         oae:position         "2134"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Push_%282009_film%29> .
//
//     _:e0-64 rdf:type oae:Entity ;
//         oae:confidence       "-3.934500644104404"^^xsd:double ;
//         oae:detectedAs       "var" ;
//         oae:position         "2172"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Value_at_risk> .
//
//     _:e0-65 rdf:type oae:Entity ;
//         oae:confidence       "-2.8257335594337816"^^xsd:double ;
//         oae:detectedAs       "async" ;
//         oae:position         "2245"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Asynchronous_communication> .
//
//     _:e0-66 rdf:type oae:Entity ;
//         oae:confidence       "-3.1111830032248085"^^xsd:double ;
//         oae:detectedAs       "src" ;
//         oae:position         "2261"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Proto-oncogene_tyrosine-protein_kinase_Src> .
//
//     _:e0-67 rdf:type oae:Entity ;
//         oae:confidence       "-0.2760230444720168"^^xsd:double ;
//         oae:detectedAs       "google analytics" ;
//         oae:position         "2343"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Google_Analytics> .
//
//     _:e0-68 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "2367"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-69 rdf:type oae:Entity ;
//         oae:confidence       "-2.7323107524307906"^^xsd:double ;
//         oae:detectedAs       "granada" ;
//         oae:position         "2567"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Granada> .
//
//     _:e0-70 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "2637"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-71 rdf:type oae:Entity ;
//         oae:confidence       "-3.199451504558889"^^xsd:double ;
//         oae:detectedAs       "ajax" ;
//         oae:position         "2653"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/AFC_Ajax> .
//
//     _:e0-72 rdf:type oae:Entity ;
//         oae:confidence       "-3.6299891657192735"^^xsd:double ;
//         oae:detectedAs       "token" ;
//         oae:position         "2583"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Security_token> .
//
//     _:e0-73 rdf:type oae:Entity ;
//         oae:confidence       "-3.199451504558889"^^xsd:double ;
//         oae:detectedAs       "ajax" ;
//         oae:position         "2674"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/AFC_Ajax> .
//
//     _:e0-74 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "2712"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-75 rdf:type oae:Entity ;
//         oae:confidence       "-3.8449928970870504"^^xsd:double ;
//         oae:detectedAs       "misc" ;
//         oae:position         "2725"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/MISC_Berhad> .
//
//     _:e0-76 rdf:type oae:Entity ;
//         oae:confidence       "-3.8449928970870504"^^xsd:double ;
//         oae:detectedAs       "misc" ;
//         oae:position         "2750"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/MISC_Berhad> .
//
//     _:e0-77 rdf:type oae:Entity ;
//         oae:confidence       "-2.6767845764682257"^^xsd:double ;
//         oae:detectedAs       "js lightbox" ;
//         oae:position         "2910"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Lightbox_%28JavaScript%29> .
//
//     _:e0-78 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "2959"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-79 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "3025"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-80 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "3004"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-81 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "3015"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-82 rdf:type oae:Entity ;
//         oae:confidence       "-0.2760230444720168"^^xsd:double ;
//         oae:detectedAs       "google analytics" ;
//         oae:position         "3063"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Google_Analytics> .
//
//     _:e0-83 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "3097"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-84 rdf:type oae:Entity ;
//         oae:confidence       "-3.105994565255031"^^xsd:double ;
//         oae:detectedAs       "themes" ;
//         oae:position         "3122"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Theme_%28narrative%29> .
//
//     _:e0-85 rdf:type oae:Entity ;
//         oae:confidence       "-3.206798671544459"^^xsd:double ;
//         oae:detectedAs       "fusion core" ;
//         oae:position         "3138"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Fusion_Core_Drum_and_Bugle_Corps> .
//
//     _:e0-86 rdf:type oae:Entity ;
//         oae:confidence       "-3.74360341862593"^^xsd:double ;
//         oae:detectedAs       "js script" ;
//         oae:position         "3151"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-87 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3170"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-88 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3206"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-89 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3244"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-90 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3285"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-91 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3323"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-92 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3383"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-93 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3417"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-94 rdf:type oae:Entity ;
//         oae:confidence       "-2.248293959859218"^^xsd:double ;
//         oae:detectedAs       "api" ;
//         oae:position         "3457"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Application_programming_interface> .
//
//     _:e0-95 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3467"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-96 rdf:type oae:Entity ;
//         oae:confidence       "-2.553828993623374"^^xsd:double ;
//         oae:detectedAs       "popup" ;
//         oae:position         "3507"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Pop-up_ad> .
//
//     _:e0-97 rdf:type oae:Entity ;
//         oae:confidence       "-3.105994565255031"^^xsd:double ;
//         oae:detectedAs       "themes" ;
//         oae:position         "3514"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Theme_%28narrative%29> .
//
//     _:e0-98 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3537"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-99 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3574"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-100 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3632"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-101 rdf:type oae:Entity ;
//         oae:confidence       "-3.935550412859875"^^xsd:double ;
//         oae:detectedAs       "node" ;
//         oae:position         "3655"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Node_%28networking%29> .
//
//     _:e0-102 rdf:type oae:Entity ;
//         oae:confidence       "-3.935550412859875"^^xsd:double ;
//         oae:detectedAs       "node" ;
//         oae:position         "3649"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Node_%28networking%29> .
//
//     _:e0-103 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3660"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-104 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3688"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-105 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3754"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-106 rdf:type oae:Entity ;
//         oae:confidence       "-2.97314267028049"^^xsd:double ;
//         oae:detectedAs       "entity" ;
//         oae:position         "3829"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Entity> .
//
//     _:e0-107 rdf:type oae:Entity ;
//         oae:confidence       "-2.97314267028049"^^xsd:double ;
//         oae:detectedAs       "entity" ;
//         oae:position         "3802"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Entity> .
//
//     _:e0-108 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3846"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-109 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3878"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-110 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3906"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-111 rdf:type oae:Entity ;
//         oae:confidence       "-3.7823583058704715"^^xsd:double ;
//         oae:detectedAs       "forum" ;
//         oae:position         "3930"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Internet_forum> .
//
//     _:e0-112 rdf:type oae:Entity ;
//         oae:confidence       "-3.7823583058704715"^^xsd:double ;
//         oae:detectedAs       "forum" ;
//         oae:position         "3923"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Internet_forum> .
//
//     _:e0-113 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3972"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-114 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3936"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-115 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "3983"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-116 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4068"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-117 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4031"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-118 rdf:type oae:Entity ;
//         oae:confidence       "-3.0447381286619484"^^xsd:double ;
//         oae:detectedAs       "ctools" ;
//         oae:position         "4073"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/CTOL> .
//
//     _:e0-119 rdf:type oae:Entity ;
//         oae:confidence       "-3.0447381286619484"^^xsd:double ;
//         oae:detectedAs       "ctools" ;
//         oae:position         "4060"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/CTOL> .
//
//     _:e0-120 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4080"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-121 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4138"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-122 rdf:type oae:Entity ;
//         oae:confidence       "-1.5482882962409832"^^xsd:double ;
//         oae:detectedAs       "lexicon" ;
//         oae:position         "4231"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Lexicon> .
//
//     _:e0-123 rdf:type oae:Entity ;
//         oae:confidence       "-1.5482882962409832"^^xsd:double ;
//         oae:detectedAs       "lexicon" ;
//         oae:position         "4217"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Lexicon> .
//
//     _:e0-124 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4226"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-125 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4188"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-126 rdf:type oae:Entity ;
//         oae:confidence       "-1.2876414031685819"^^xsd:double ;
//         oae:detectedAs       "lightbox" ;
//         oae:position         "4284"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Lightbox_%28JavaScript%29> .
//
//     _:e0-127 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4279"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-128 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4239"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-129 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4330"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-130 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4293"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-131 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4342"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-132 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4404"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-133 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "4506"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-134 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "4489"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-135 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4454"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-136 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4516"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-137 rdf:type oae:Entity ;
//         oae:confidence       "-2.7595156902652205"^^xsd:double ;
//         oae:detectedAs       "taxonomy" ;
//         oae:position         "4562"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Taxonomy_%28biology%29> .
//
//     _:e0-138 rdf:type oae:Entity ;
//         oae:confidence       "-2.7595156902652205"^^xsd:double ;
//         oae:detectedAs       "taxonomy" ;
//         oae:position         "4545"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Taxonomy_%28biology%29> .
//
//     _:e0-139 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4578"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-140 rdf:type oae:Entity ;
//         oae:confidence       "-1.5590107453135096"^^xsd:double ;
//         oae:detectedAs       "ie7" ;
//         oae:position         "4636"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Internet_Explorer_7> .
//
//     _:e0-141 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4640"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-142 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4747"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-143 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "4698"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-144 rdf:type oae:Entity ;
// ...
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Mode_%28statistics%29> .
//
//     _:e0-200 rdf:type oae:Entity ;
//         oae:confidence       "-3.8925796192851365"^^xsd:double ;
//         oae:detectedAs       "mode" ;
//         oae:position         "5493"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Mode_%28statistics%29> .
//
//     _:e0-201 rdf:type oae:Entity ;
//         oae:confidence       "-3.9938617703716934"^^xsd:double ;
//         oae:detectedAs       "manual" ;
//         oae:position         "5500"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Manual_transmission> .
//
//     _:e0-202 rdf:type oae:Entity ;
//         oae:confidence       "-2.189936208696481"^^xsd:double ;
//         oae:detectedAs       "opacity" ;
//         oae:position         "5836"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Opacity_%28optics%29> .
//
//     _:e0-203 rdf:type oae:Entity ;
//         oae:confidence       "-2.729544952699074"^^xsd:double ;
//         oae:detectedAs       "fff" ;
//         oae:position         "5804"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/French_Football_Federation> .
//
//     _:e0-204 rdf:type oae:Entity ;
//         oae:confidence       "-3.635701344297065"^^xsd:double ;
//         oae:detectedAs       "box" ;
//         oae:position         "5792"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Box> .
//
//     _:e0-205 rdf:type oae:Entity ;
//         oae:confidence       "-3.90152382942325"^^xsd:double ;
//         oae:detectedAs       "font color" ;
//         oae:position         "5773"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Type_color> .
//
//     _:e0-206 rdf:type oae:Entity ;
//         oae:confidence       "-0.36517504009217827"^^xsd:double ;
//         oae:detectedAs       "target" ;
//         oae:position         "6134"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Target_Corporation> .
//
//     _:e0-207 rdf:type oae:Entity ;
//         oae:confidence       "-0.8586076172772598"^^xsd:double ;
//         oae:detectedAs       "7z" ;
//         oae:position         "7336"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/7z> .
//
//     _:e0-208 rdf:type oae:Entity ;
//         oae:confidence       "-1.2876414031685819"^^xsd:double ;
//         oae:detectedAs       "lightbox" ;
//         oae:position         "6684"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Lightbox_%28JavaScript%29> .
//
//     _:e0-209 rdf:type oae:Entity ;
//         oae:confidence       "-1.2876414031685819"^^xsd:double ;
//         oae:detectedAs       "lightbox" ;
//         oae:position         "6654"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Lightbox_%28JavaScript%29> .
//
//     _:e0-210 rdf:type oae:Entity ;
//         oae:confidence       "-1.3142764499950788"^^xsd:double ;
//         oae:detectedAs       "msp" ;
//         oae:position         "7439"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Management_services_organization> .
//
//     _:e0-211 rdf:type oae:Entity ;
//         oae:confidence       "-1.509193655233946"^^xsd:double ;
//         oae:detectedAs       "g" ;
//         oae:position         "7423"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/G> .
//
//     _:e0-212 rdf:type oae:Entity ;
//         oae:confidence       "-1.509193655233946"^^xsd:double ;
//         oae:detectedAs       "g" ;
//         oae:position         "7407"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/G> .
//
//     _:e0-213 rdf:type oae:Entity ;
//         oae:confidence       "-1.5123522606838364"^^xsd:double ;
//         oae:detectedAs       "torrent" ;
//         oae:position         "7490"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Torrent_file> .
//
//     _:e0-214 rdf:type oae:Entity ;
//         oae:confidence       "-1.5745837897123491"^^xsd:double ;
//         oae:detectedAs       "gif" ;
//         oae:position         "7383"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/GIF> .
//
//     _:e0-215 rdf:type oae:Entity ;
//         oae:confidence       "-1.649555049765405"^^xsd:double ;
//         oae:detectedAs       "asx" ;
//         oae:position         "7355"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Australian_Securities_Exchange> .
//
//     _:e0-216 rdf:type oae:Entity ;
//         oae:confidence       "-1.7167357580512208"^^xsd:double ;
//         oae:detectedAs       "wav" ;
//         oae:position         "7502"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/WAV> .
//
//     _:e0-217 rdf:type oae:Entity ;
//         oae:confidence       "-1.7872319097337315"^^xsd:double ;
//         oae:detectedAs       "flv" ;
//         oae:position         "7379"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Flash_Video> .
//
//     _:e0-218 rdf:type oae:Entity ;
//         oae:confidence       "-1.7913469484060516"^^xsd:double ;
//         oae:detectedAs       "pdf" ;
//         oae:position         "7443"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Portable_Document_Format> .
//
//     _:e0-219 rdf:type oae:Entity ;
//         oae:confidence       "-1.838258941573225"^^xsd:double ;
//         oae:detectedAs       "txt" ;
//         oae:position         "7498"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Text_file> .
//
//     _:e0-220 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "7030"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-221 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "6997"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-222 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "6971"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-223 rdf:type oae:Entity ;
//         oae:confidence       "-1.9199372895028164"^^xsd:double ;
//         oae:detectedAs       "slideshow" ;
//         oae:position         "6720"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Slide_show> .
//
//     _:e0-224 rdf:type oae:Entity ;
//         oae:confidence       "-1.9948936833770872"^^xsd:double ;
//         oae:detectedAs       "zoom" ;
//         oae:position         "6556"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Zoom_%28comics%29> .
//
//     _:e0-225 rdf:type oae:Entity ;
//         oae:confidence       "-1.9948936833770872"^^xsd:double ;
//         oae:detectedAs       "zoom" ;
//         oae:position         "6026"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Zoom_%28comics%29> .
//
//     _:e0-226 rdf:type oae:Entity ;
//         oae:confidence       "-2.05046820011555"^^xsd:double ;
//         oae:detectedAs       "avi" ;
//         oae:position         "7359"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Audio_Video_Interleave> .
//
//     _:e0-227 rdf:type oae:Entity ;
//         oae:confidence       "-2.2965099109977194"^^xsd:double ;
//         oae:detectedAs       "xml" ;
//         oae:position         "7522"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/XML> .
//
//     _:e0-228 rdf:type oae:Entity ;
//         oae:confidence       "-2.3313093834462535"^^xsd:double ;
//         oae:detectedAs       "iframe" ;
//         oae:position         "7203"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTML_element> .
//
//     _:e0-229 rdf:type oae:Entity ;
//         oae:confidence       "-2.3313093834462535"^^xsd:double ;
//         oae:detectedAs       "iframe" ;
//         oae:position         "7183"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTML_element> .
//
//     _:e0-230 rdf:type oae:Entity ;
//         oae:confidence       "-2.3313093834462535"^^xsd:double ;
//         oae:detectedAs       "iframe" ;
//         oae:position         "7164"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTML_element> .
//
//     _:e0-231 rdf:type oae:Entity ;
//         oae:confidence       "-2.3347042436723737"^^xsd:double ;
//         oae:detectedAs       "mov" ;
//         oae:position         "7426"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Varistor> .
//
//     _:e0-232 rdf:type oae:Entity ;
//         oae:confidence       "-2.3553673165195197"^^xsd:double ;
//         oae:detectedAs       "msi" ;
//         oae:position         "7435"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Motorola_Solutions> .
//
//     _:e0-233 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "6301"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-234 rdf:type oae:Entity ;
//         oae:confidence       "-2.770711094424662"^^xsd:double ;
//         oae:detectedAs       "asf" ;
//         oae:position         "7351"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Advanced_Systems_Format> .
//
//     _:e0-235 rdf:type oae:Entity ;
//         oae:confidence       "-2.871817781715675"^^xsd:double ;
//         oae:detectedAs       "aac" ;
//         oae:position         "7339"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/American_Athletic_Conference> .
//
//     _:e0-236 rdf:type oae:Entity ;
//         oae:confidence       "-2.89113571194738"^^xsd:double ;
//         oae:detectedAs       "interval" ;
//         oae:position         "6981"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Interval_%28mathematics%29> .
//
//     _:e0-237 rdf:type oae:Entity ;
//         oae:confidence       "-2.9861811331923485"^^xsd:double ;
//         oae:detectedAs       "mp" ;
//         oae:position         "7412"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Member_of_parliament> .
//
//     _:e0-238 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "7409"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-239 rdf:type oae:Entity ;
//         oae:confidence       "-3.1083968476285535"^^xsd:double ;
//         oae:detectedAs       "nav" ;
//         oae:position         "6046"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Net_asset_value> .
//
//     _:e0-240 rdf:type oae:Entity ;
//         oae:confidence       "-3.2220987191988324"^^xsd:double ;
//         oae:detectedAs       "arj" ;
//         oae:position         "7347"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/ARJ> .
//
//     _:e0-241 rdf:type oae:Entity ;
//         oae:confidence       "-3.2368205538525885"^^xsd:double ;
//         oae:detectedAs       "8" ;
//         oae:position         "5848"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/8> .
//
//     _:e0-242 rdf:type oae:Entity ;
//         oae:confidence       "-3.3115905247847945"^^xsd:double ;
//         oae:detectedAs       "qtm" ;
//         oae:position         "7460"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Quantum_Corporation> .
//
//     _:e0-243 rdf:type oae:Entity ;
//         oae:confidence       "-3.382654716476455"^^xsd:double ;
//         oae:detectedAs       "32" ;
//         oae:position         "6585"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/32> .
//
//     _:e0-244 rdf:type oae:Entity ;
//         oae:confidence       "-3.3961414896925275"^^xsd:double ;
//         oae:detectedAs       "png" ;
//         oae:position         "7452"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Portable_Network_Graphics> .
//
//     _:e0-245 rdf:type oae:Entity ;
//         oae:confidence       "-3.425085775224592"^^xsd:double ;
//         oae:detectedAs       "bin" ;
//         oae:position         "7363"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Bing> .
//
//     _:e0-246 rdf:type oae:Entity ;
//         oae:confidence       "-3.4478486753767474"^^xsd:double ;
//         oae:detectedAs       "tgz" ;
//         oae:position         "7486"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tar_%28computing%29> .
//
//     _:e0-247 rdf:type oae:Entity ;
//         oae:confidence       "-3.485964189310022"^^xsd:double ;
//         oae:detectedAs       "enable" ;
//         oae:position         "7221"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Enabling> .
//
//     _:e0-248 rdf:type oae:Entity ;
//         oae:confidence       "-3.485964189310022"^^xsd:double ;
//         oae:detectedAs       "enable" ;
//         oae:position         "6941"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Enabling> .
//
//     _:e0-249 rdf:type oae:Entity ;
//         oae:confidence       "-3.485964189310022"^^xsd:double ;
//         oae:detectedAs       "enable" ;
//         oae:position         "6464"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Enabling> .
//
//     _:e0-250 rdf:type oae:Entity ;
//         oae:confidence       "-3.485964189310022"^^xsd:double ;
//         oae:detectedAs       "enable" ;
//         oae:position         "6443"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Enabling> .
//
//     _:e0-251 rdf:type oae:Entity ;
//         oae:confidence       "-3.619886328091931"^^xsd:double ;
//         oae:detectedAs       "sit tar" ;
//         oae:position         "7478"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Sitar> .
//
//     _:e0-252 rdf:type oae:Entity ;
//         oae:confidence       "-3.6419201364025042"^^xsd:double ;
//         oae:detectedAs       "1 show" ;
//         oae:position         "6051"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_One_Show> .
//
//     _:e0-253 rdf:type oae:Entity ;
//         oae:confidence       "-3.7524315335716176"^^xsd:double ;
//         oae:detectedAs       "hqx" ;
//         oae:position         "7395"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hqx> .
//
//     _:e0-254 rdf:type oae:Entity ;
//         oae:confidence       "-3.753250971479739"^^xsd:double ;
//         oae:detectedAs       "ra" ;
//         oae:position         "7465"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Ra> .
//
//     _:e0-255 rdf:type oae:Entity ;
//         oae:confidence       "-3.869061885665475"^^xsd:double ;
//         oae:detectedAs       "download" ;
//         oae:position         "6419"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Download.com> .
//
//     _:e0-256 rdf:type oae:Entity ;
//         oae:confidence       "-3.8827211981375753"^^xsd:double ;
//         oae:detectedAs       "exe" ;
//         oae:position         "7375"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/.exe> .
//
//     _:e0-257 rdf:type oae:Entity ;
//         oae:confidence       "-3.891220541064175"^^xsd:double ;
//         oae:detectedAs       "5000" ;
//         oae:position         "6991"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/5000_%28number%29> .
//
//     _:e0-258 rdf:type oae:Entity ;
//         oae:confidence       "-3.935550412859875"^^xsd:double ;
//         oae:detectedAs       "node" ;
//         oae:position         "6628"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Node_%28networking%29> .
//
//     _:e0-259 rdf:type oae:Entity ;
//         oae:confidence       "-3.935550412859875"^^xsd:double ;
//         oae:detectedAs       "node" ;
//         oae:position         "6086"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Node_%28networking%29> .

// %% [markdown]
// # Sort and store with headers

// %%
val headers = TripleHeader.append("oae" -> "http://www.ics.forth.gr/isl/oae/core#")

// %%
val triples = ArchiveSpark2Triples.toStringsSorted(headers, documentTriples, sameAsTriples, versionTriples)

// %%
triples.saveAsTextFile(s"$collection-Triples1.gz", classOf[GzipCodec])
