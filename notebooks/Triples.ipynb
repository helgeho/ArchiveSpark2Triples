// %% [markdown]
// This notebook requires FEL4ArchiveSpark: https://github.com/helgeho/FEL4ArchiveSpark

// %%
import de.l3s.archivespark._
import de.l3s.archivespark.implicits._
import de.l3s.archivespark.specific.warc._
import de.l3s.archivespark.specific.warc.specs._
import de.l3s.archivespark.specific.warc.implicits._
import de.l3s.archivespark.enrich._
import de.l3s.archivespark.enrich.functions._
import de.l3s.archivespark.enrich.dataloads._
import de.l3s.archivespark.enrichfunctions.fel._
import de.l3s.archivespark2triples._
import org.apache.hadoop.io.compress.GzipCodec

// %% [markdown]
// # Load the FEL model file

// %%
val modelFile = "english-nov15.hash"
sc.addFile("hdfs:///user/holzmann/" + modelFile)

// %% [markdown]
// # Initialize the web archive collection

// %%
val collection = "ArchiveIt-Collection-2950"
val cdxPath = s"/data/archiveit/$collection/cdx/*.cdx.gz"
val warcPath = s"/data/archiveit/$collection/warc"

// %%
val records = ArchiveSpark.load(sc, WarcCdxHdfsSpec(cdxPath, warcPath))

// %%
records.peekJson
// Out:
// {
//   "record":{
//     "redirectUrl":"-",
//     "timestamp":"20111222021216",
//     "digest":"ZPP7YDXYWOVKO3RILANIHUPL3REXJDZE",
//     "originalUrl":"http://184.107.185.46/newsbeast/index.php?w=500&h=300&b=http://www.newsbeast.gr/files/1/2011/06/15/sintagma_1_5.jpg",
//     "surtUrl":"46,185,107,184)/newsbeast/index.php?b=http://www.newsbeast.gr/files/1/2011/06/15/sintagma_1_5.jpg&h=300&w=500",
//     "mime":"text/html",
//     "compressedSize":464,
//     "meta":"-",
//     "status":404
//   }
// }

// %% [markdown]
// # Select successful responses of type HTML and detect duplicates

// %%
val responses = records.filter(r => r.status == 200 && r.mime == "text/html")

// %%
val earliestResponses = responses.map(r => ((r.surtUrl, r.digest), r)).reduceByKey{(r1, r2) =>
    if (r1.time < r2.time) r1 else r2
}

// %%
val duplicates = records.map(r => ((r.surtUrl, r.digest), r)).join(earliestResponses).map{case (_, records) => records}.filter{case (r1, r2) => r1.time != r2.time}

// %% [markdown]
// # Generate *ArchivedDocument* triples representing its versions

// %%
val versions = earliestResponses.map{case (_, r) => r}.union(duplicates.map{case (r1, r2) => r1})

// %%
versions.count
// Out:
// 10503433

// %%
val documentTriples = ArchiveSpark2Triples.generateDocs(versions)

// %%
println(documentTriples.take(1).head)
// Out:
// <org,occupyalabama)/forum/showthread.php?goto=nextnewest&t=161> rdf:type owa:ArchivedDocument ;
//     owa:numOfCaptures    "6"^^xsd:integer ;
//     owa:firstCapture     "2011-12-03T05:56:19"^^xsd:date ;
//     owa:lastCapture      "2012-01-03T03:36:09"^^xsd:date ;
//     dc:hasVersion        <https://web.archive.org/web/20111203055619/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111210061229/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111217055735/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111220030152/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111227031921/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20120103033609/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest> .

// %% [markdown]
// # Create "*sameAs* triples" from duplicates

// %%
val sameAsTriples = ArchiveSpark2Triples.generateSameAsVersions(duplicates)

// %%
println(sameAsTriples.take(1).head)
// Out:
// <https://web.archive.org/web/20120105062548/http://www.livestream.com/forum/showpost.php?p=18958&postcount=9> rdf:type owa:VersionedDocument ;
//     dc:date              "2012-01-05T06:25:48"^^xsd:date ;
//     owl:sameAs           <https://web.archive.org/web/20111229064632/http://www.livestream.com/forum/showpost.php?p=18958&postcount=9> .

// %% [markdown]
// # Generate *VersionedDocument* triples with title and entities

// %%
val responsesRepartitioned = earliestResponses.map{case (_, r) => r}.repartition(1000)

// %%
val title = HtmlText.of(Html.first("title"))
val responsesWithTitles = responsesRepartitioned.enrich(title)

// %%
val fel = FEL(scoreThreshold = -5, modelFile = modelFile).on(HtmlText)
val responsesWithEntities = responsesWithTitles.enrich(fel)

// %%
responsesWithEntities.peekJson
// Out:
// {
//   "record":{
//     "redirectUrl":"-",
//     "timestamp":"20120116222507",
//     "digest":"OTM4ILGHNX4HTAEEN7U7XZTMKO2EVJ3X",
//     "originalUrl":"https://www.facebook.com/help/mobile/iphone",
//     "surtUrl":"com,facebook)/help/mobile/iphone",
//     "mime":"text/html",
//     "compressedSize":9206,
//     "meta":"-",
//     "status":200
//   },
//   "payload":{
//     "string":{
//       "html":{
//         "title":{
//           "text":"Facebook for iPhone App - Facebook Help Center | Facebook"
//         },
//         "body":{
//           "text":{
//             "entities":[
//               {
//                 "span":"fb",
//                 "endOffset":10444,
//                 "score":-0.18161437557306173,
//                 "annotation":"Facebook",
//                 "startOffset":10442
//               },
//               {
//           ...

// %%
val versionTriples = ArchiveSpark2Triples.generateVersionsMapped(responsesWithEntities) {(record, uid, doc) =>
    val recordTitle = record.value(title).getOrElse("")
    val recordEntities = record.value(fel).getOrElse(Seq.empty)
    doc.appendTriples("dc:title", s"""\"recordTitle\"""").appendChildren("schema:mentions", {
        recordEntities.zipWithIndex.map{case (entity, i) => TripleDoc(
            s"_:e$uid-$i",
            "oae:Entity",
            Seq(
                "oae:confidence" -> Seq(s""""${entity.score}"^^xsd:double"""),
                "oae:detectedAs" -> Seq(s"""\"${entity.span}\""""),
                "oae:position" -> Seq(s""""${entity.startOffset}"^^xsd:integer"""),
                "oae:hasMatchedURI" -> Seq(s"<http://dbpedia.org/resource/${entity.annotation}>")
            )
        )}
    })
}

// %%
println(versionTriples.take(1).head)
// Out:
// <https://web.archive.org/web/20120116222507/https://www.facebook.com/help/mobile/iphone> rdf:type owa:VersionedDocument ;
//     dc:date              "2012-01-16T22:25:07"^^xsd:date ;
//     dc:format            "text/html" ;
//     dc:title             "recordTitle" ;
//     schema:mentions      _:e0-0,
//                          _:e0-1,
//                          _:e0-2,
//                          _:e0-3,
//                          _:e0-4,
//                          _:e0-5,
//                          _:e0-6,
//                          _:e0-7,
//                          _:e0-8,
//                          _:e0-9,
//                          _:e0-10,
//                          _:e0-11,
//                          _:e0-12,
//                          _:e0-13,
//                          _:e0-14,
//                          _:e0-15,
//                          _:e0-16,
//                          _:e0-17,
//                          _:e0-18,
//                          _:e0-19,
//                          _:e0-20,
//                          _:e0-21,
//                          _:e0-22,
//                          _:e0-23,
//                          _:e0-24,
//                          _:e0-25,
//                          _:e0-26,
//                          _:e0-27,
//                          _:e0-28,
//                          _:e0-29,
//                          _:e0-30,
//                          _:e0-31,
//                          _:e0-32,
//                          _:e0-33,
//                          _:e0-34,
//                          _:e0-35,
//                          _:e0-36,
//                          _:e0-37,
//                          _:e0-38,
//                          _:e0-39,
//                          _:e0-40,
//                          _:e0-41,
//                          _:e0-42,
//                          _:e0-43,
//                          _:e0-44,
//                          _:e0-45,
//                          _:e0-46,
//                          _:e0-47,
//                          _:e0-48,
//                          _:e0-49,
//                          _:e0-50,
//                          _:e0-51,
//                          _:e0-52,
//                          _:e0-53,
//                          _:e0-54,
//                          _:e0-55,
//                          _:e0-56,
//                          _:e0-57,
//                          _:e0-58,
//                          _:e0-59,
//                          _:e0-60,
//                          _:e0-61,
//                          _:e0-62,
//                          _:e0-63,
//                          _:e0-64,
//                          _:e0-65,
//                          _:e0-66,
//                          _:e0-67,
//                          _:e0-68,
//                          _:e0-69,
//                          _:e0-70,
//                          _:e0-71,
//                          _:e0-72,
//                          _:e0-73,
//                          _:e0-74,
//                          _:e0-75,
//                          _:e0-76,
//                          _:e0-77,
//                          _:e0-78,
//                          _:e0-79,
//                          _:e0-80,
//                          _:e0-81,
//                          _:e0-82,
//                          _:e0-83,
//                          _:e0-84,
//                          _:e0-85,
//                          _:e0-86,
//                          _:e0-87,
//                          _:e0-88,
//                          _:e0-89,
//                          _:e0-90,
//                          _:e0-91,
//                          _:e0-92,
//                          _:e0-93,
//                          _:e0-94,
//                          _:e0-95,
//                          _:e0-96,
//                          _:e0-97,
//                          _:e0-98,
//                          _:e0-99,
//                          _:e0-100,
//                          _:e0-101,
//                          _:e0-102,
//                          _:e0-103,
//                          _:e0-104,
//                          _:e0-105,
//                          _:e0-106,
//                          _:e0-107,
//                          _:e0-108,
//                          _:e0-109,
//                          _:e0-110,
//                          _:e0-111,
//                          _:e0-112,
//                          _:e0-113,
//                          _:e0-114,
//                          _:e0-115,
//                          _:e0-116,
//                          _:e0-117,
//                          _:e0-118,
//                          _:e0-119,
//                          _:e0-120,
//                          _:e0-121,
//                          _:e0-122,
//                          _:e0-123,
//                          _:e0-124,
//                          _:e0-125,
//                          _:e0-126,
//                          _:e0-127,
//                          _:e0-128,
//                          _:e0-129,
//                          _:e0-130,
//                          _:e0-131,
//                          _:e0-132,
//                          _:e0-133,
//                          _:e0-134,
//                          _:e0-135,
//                          _:e0-136,
//                          _:e0-137,
//                          _:e0-138,
//                          _:e0-139,
//                          _:e0-140,
//                          _:e0-141,
//                          _:e0-142,
//                          _:e0-143,
//                          _:e0-144,
//                          _:e0-145,
//                          _:e0-146,
//                          _:e0-147,
//                          _:e0-148,
//                          _:e0-149,
//                          _:e0-150,
//                          _:e0-151,
//                          _:e0-152,
//                          _:e0-153,
//                          _:e0-154,
//                          _:e0-155,
//                          _:e0-156,
//                          _:e0-157,
//                          _:e0-158,
//                          _:e0-159,
//                          _:e0-160,
//                          _:e0-161,
//                          _:e0-162,
//                          _:e0-163,
//                          _:e0-164,
//                          _:e0-165,
//                          _:e0-166,
//                          _:e0-167,
//                          _:e0-168,
//                          _:e0-169,
//                          _:e0-170,
//                          _:e0-171,
//                          _:e0-172,
//                          _:e0-173,
//                          _:e0-174,
//                          _:e0-175,
//                          _:e0-176,
//                          _:e0-177,
//                          _:e0-178,
//                          _:e0-179,
//                          _:e0-180,
//                          _:e0-181,
//                          _:e0-182,
//                          _:e0-183,
//                          _:e0-184,
//                          _:e0-185,
//                          _:e0-186,
//                          _:e0-187,
//                          _:e0-188,
//                          _:e0-189,
//                          _:e0-190,
//                          _:e0-191,
//                          _:e0-192,
//                          _:e0-193,
//                          _:e0-194,
//                          _:e0-195,
//                          _:e0-196,
//                          _:e0-197,
//                          _:e0-198,
//                          _:e0-199,
//                          _:e0-200,
//                          _:e0-201,
//                          _:e0-202,
//                          _:e0-203,
//                          _:e0-204,
//                          _:e0-205,
//                          _:e0-206,
//                          _:e0-207,
//                          _:e0-208,
//                          _:e0-209,
//                          _:e0-210,
//                          _:e0-211,
//                          _:e0-212,
//                          _:e0-213,
//                          _:e0-214,
//                          _:e0-215,
//                          _:e0-216,
//                          _:e0-217,
//                          _:e0-218,
//                          _:e0-219,
//                          _:e0-220,
//                          _:e0-221,
//                          _:e0-222,
//                          _:e0-223,
//                          _:e0-224,
//                          _:e0-225,
//                          _:e0-226,
//                          _:e0-227,
//                          _:e0-228,
//                          _:e0-229,
//                          _:e0-230,
//                          _:e0-231,
//                          _:e0-232,
//                          _:e0-233,
//                          _:e0-234,
//                          _:e0-235,
//                          _:e0-236,
//                          _:e0-237,
//                          _:e0-238,
//                          _:e0-239,
//                          _:e0-240,
//                          _:e0-241,
//                          _:e0-242,
//                          _:e0-243,
//                          _:e0-244,
//                          _:e0-245,
//                          _:e0-246,
//                          _:e0-247,
//                          _:e0-248,
//                          _:e0-249,
//                          _:e0-250,
//                          _:e0-251,
//                          _:e0-252,
//                          _:e0-253,
//                          _:e0-254,
//                          _:e0-255,
//                          _:e0-256,
//                          _:e0-257,
//                          _:e0-258,
//                          _:e0-259,
//                          _:e0-260,
//                          _:e0-261,
//                          _:e0-262,
//                          _:e0-263,
//                          _:e0-264,
//                          _:e0-265,
//                          _:e0-266,
//                          _:e0-267,
//                          _:e0-268,
//                          _:e0-269,
//                          _:e0-270,
//                          _:e0-271,
//                          _:e0-272,
//                          _:e0-273,
//                          _:e0-274,
//                          _:e0-275,
//                          _:e0-276,
//                          _:e0-277,
//                          _:e0-278,
//                          _:e0-279,
//                          _:e0-280,
//                          _:e0-281,
//                          _:e0-282,
//                          _:e0-283,
//                          _:e0-284,
//                          _:e0-285,
//                          _:e0-286,
//                          _:e0-287,
//                          _:e0-288,
//                          _:e0-289,
//                          _:e0-290,
//                          _:e0-291,
//                          _:e0-292,
//                          _:e0-293,
//                          _:e0-294,
//                          _:e0-295,
//                          _:e0-296,
//                          _:e0-297,
//                          _:e0-298,
//                          _:e0-299,
//                          _:e0-300,
//                          _:e0-301,
//                          _:e0-302,
//                          _:e0-303,
//                          _:e0-304,
//                          _:e0-305,
//                          _:e0-306,
//                          _:e0-307,
//                          _:e0-308,
//                          _:e0-309,
//                          _:e0-310,
//                          _:e0-311,
//                          _:e0-312,
//                          _:e0-313,
//                          _:e0-314,
//                          _:e0-315,
//                          _:e0-316,
//                          _:e0-317,
//                          _:e0-318,
//                          _:e0-319,
//                          _:e0-320,
//                          _:e0-321,
//                          _:e0-322,
//                          _:e0-323,
//                          _:e0-324,
//                          _:e0-325,
//                          _:e0-326,
//                          _:e0-327,
//                          _:e0-328,
//                          _:e0-329,
//                          _:e0-330,
//                          _:e0-331,
//                          _:e0-332,
//                          _:e0-333,
//                          _:e0-334,
//                          _:e0-335,
//                          _:e0-336,
//                          _:e0-337,
//                          _:e0-338,
//                          _:e0-339,
//                          _:e0-340,
//                          _:e0-341,
//                          _:e0-342,
//                          _:e0-343,
//                          _:e0-344,
//                          _:e0-345,
//                          _:e0-346,
//                          _:e0-347,
//                          _:e0-348,
//                          _:e0-349,
//                          _:e0-350,
//                          _:e0-351,
//                          _:e0-352,
//                          _:e0-353,
//                          _:e0-354,
//                          _:e0-355,
//                          _:e0-356,
//                          _:e0-357,
//                          _:e0-358,
//                          _:e0-359,
//                          _:e0-360,
//                          _:e0-361,
//                          _:e0-362,
//                          _:e0-363,
//                          _:e0-364,
//                          _:e0-365,
//                          _:e0-366,
//                          _:e0-367,
//                          _:e0-368,
//                          _:e0-369,
//                          _:e0-370,
//                          _:e0-371,
//                          _:e0-372,
//                          _:e0-373,
//                          _:e0-374,
//                          _:e0-375,
//                          _:e0-376,
//                          _:e0-377,
//                          _:e0-378,
//                          _:e0-379,
//                          _:e0-380,
//                          _:e0-381,
//                          _:e0-382,
//                          _:e0-383,
//                          _:e0-384,
//                          _:e0-385,
//                          _:e0-386,
//                          _:e0-387,
//                          _:e0-388,
//                          _:e0-389,
//                          _:e0-390 .
//
//     _:e0-0 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "10442"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-1 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "10338"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-2 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "10233"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-3 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "10129"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-4 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "10026"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-5 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "9923"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-6 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "9821"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-7 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "9718"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-8 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "9615"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-9 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "9512"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-10 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "8320"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-11 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "8288"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-12 rdf:type oae:Entity ;
//         oae:confidence       "-0.18161437557306173"^^xsd:double ;
//         oae:detectedAs       "fb" ;
//         oae:position         "8112"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-13 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "5877"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-14 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "4609"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-15 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "4451"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-16 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "604"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-17 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "471"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-18 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "10870"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-19 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7630"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-20 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7528"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-21 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7426"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-22 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7324"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-23 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7222"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-24 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7120"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-25 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "7018"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-26 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6916"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-27 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6814"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-28 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6682"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-29 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6564"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-30 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6460"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-31 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6356"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-32 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6238"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-33 rdf:type oae:Entity ;
//         oae:confidence       "-0.6235923795397887"^^xsd:double ;
//         oae:detectedAs       "facebook com" ;
//         oae:position         "6120"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-34 rdf:type oae:Entity ;
//         oae:confidence       "-0.7706338807359006"^^xsd:double ;
//         oae:detectedAs       "javascript" ;
//         oae:position         "10780"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-35 rdf:type oae:Entity ;
//         oae:confidence       "-0.860123826836972"^^xsd:double ;
//         oae:detectedAs       "arbiter" ;
//         oae:position         "8865"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Arbiter_%28Halo%29> .
//
//     _:e0-36 rdf:type oae:Entity ;
//         oae:confidence       "-0.860123826836972"^^xsd:double ;
//         oae:detectedAs       "arbiter" ;
//         oae:position         "8814"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Arbiter_%28Halo%29> .
//
//     _:e0-37 rdf:type oae:Entity ;
//         oae:confidence       "-0.860123826836972"^^xsd:double ;
//         oae:detectedAs       "arbiter" ;
//         oae:position         "8721"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Arbiter_%28Halo%29> .
//
//     _:e0-38 rdf:type oae:Entity ;
//         oae:confidence       "-0.860123826836972"^^xsd:double ;
//         oae:detectedAs       "arbiter" ;
//         oae:position         "8638"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Arbiter_%28Halo%29> .
//
//     _:e0-39 rdf:type oae:Entity ;
//         oae:confidence       "-1.2887856212557103"^^xsd:double ;
//         oae:detectedAs       "discover" ;
//         oae:position         "102"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Discover_Card> .
//
//     _:e0-40 rdf:type oae:Entity ;
//         oae:confidence       "-1.312027694302609"^^xsd:double ;
//         oae:detectedAs       "about facebook" ;
//         oae:position         "42"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-41 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "5804"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-42 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "5254"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-43 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "5006"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-44 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "4293"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-45 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "3829"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-46 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "3108"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-47 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "2375"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-48 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "2118"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-49 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "1552"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-50 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "1046"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-51 rdf:type oae:Entity ;
//         oae:confidence       "-1.4925230755256713"^^xsd:double ;
//         oae:detectedAs       "dom html" ;
//         oae:position         "7736"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Document_Object_Model> .
//
//     _:e0-52 rdf:type oae:Entity ;
//         oae:confidence       "-1.509193655233946"^^xsd:double ;
//         oae:detectedAs       "g" ;
//         oae:position         "6727"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/G> .
//
//     _:e0-53 rdf:type oae:Entity ;
//         oae:confidence       "-1.5544324538570433"^^xsd:double ;
//         oae:detectedAs       "s e s" ;
//         oae:position         "10569"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/S.E.S._%28band%29> .
//
//     _:e0-54 rdf:type oae:Entity ;
//         oae:confidence       "-1.6519176628701173"^^xsd:double ;
//         oae:detectedAs       "https www facebook com" ;
//         oae:position         "10937"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-55 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "11123"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-56 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "11022"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-57 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "8980"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-58 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "8935"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-59 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "7685"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-60 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "6737"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-61 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "6042"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-62 rdf:type oae:Entity ;
//         oae:confidence       "-1.702211930842114"^^xsd:double ;
//         oae:detectedAs       "the conversation" ;
//         oae:position         "1866"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Conversation> .
//
//     _:e0-63 rdf:type oae:Entity ;
//         oae:confidence       "-1.702211930842114"^^xsd:double ;
//         oae:detectedAs       "the conversation" ;
//         oae:position         "1705"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Conversation> .
//
//     _:e0-64 rdf:type oae:Entity ;
//         oae:confidence       "-1.8637830295885438"^^xsd:double ;
//         oae:detectedAs       "roadrunner" ;
//         oae:position         "8840"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Greater_roadrunner> .
//
//     _:e0-65 rdf:type oae:Entity ;
//         oae:confidence       "-1.8637830295885438"^^xsd:double ;
//         oae:detectedAs       "roadrunner" ;
//         oae:position         "8701"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Greater_roadrunner> .
//
//     _:e0-66 rdf:type oae:Entity ;
//         oae:confidence       "-1.8641069463742703"^^xsd:double ;
//         oae:detectedAs       "typeahead" ;
//         oae:position         "9204"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Typeahead> .
//
//     _:e0-67 rdf:type oae:Entity ;
//         oae:confidence       "-1.8641069463742703"^^xsd:double ;
//         oae:detectedAs       "typeahead" ;
//         oae:position         "9122"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Typeahead> .
//
//     _:e0-68 rdf:type oae:Entity ;
//         oae:confidence       "-1.8650690449700142"^^xsd:double ;
//         oae:detectedAs       "the guest" ;
//         oae:position         "3720"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Guest_%28film%29> .
//
//     _:e0-69 rdf:type oae:Entity ;
//         oae:confidence       "-1.8677350261249064"^^xsd:double ;
//         oae:detectedAs       "dom" ;
//         oae:position         "8402"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Document_Object_Model> .
//
//     _:e0-70 rdf:type oae:Entity ;
//         oae:confidence       "-1.8677350261249064"^^xsd:double ;
//         oae:detectedAs       "dom" ;
//         oae:position         "7932"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Document_Object_Model> .
//
//     _:e0-71 rdf:type oae:Entity ;
//         oae:confidence       "-1.8677350261249064"^^xsd:double ;
//         oae:detectedAs       "dom" ;
//         oae:position         "7713"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Document_Object_Model> .
//
//     _:e0-72 rdf:type oae:Entity ;
//         oae:confidence       "-1.8950014000691606"^^xsd:double ;
//         oae:detectedAs       "tooltip" ;
//         oae:position         "8514"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tooltip> .
//
//     _:e0-73 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "8338"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-74 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "8304"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-75 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "8130"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-76 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6729"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-77 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6634"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-78 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6611"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-79 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6530"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-80 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6507"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-81 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6426"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-82 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6403"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-83 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6308"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-84 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6285"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-85 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6190"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-86 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6167"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-87 rdf:type oae:Entity ;
//         oae:confidence       "-2.055881989684264"^^xsd:double ;
//         oae:detectedAs       "css" ;
//         oae:position         "6086"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cascading_Style_Sheets> .
//
//     _:e0-88 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "5583"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-89 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "5426"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-90 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "1368"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-91 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "1210"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-92 rdf:type oae:Entity ;
//         oae:confidence       "-2.1636969052308817"^^xsd:double ;
//         oae:detectedAs       "yg" ;
//         oae:position         "7658"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/YG_%28rapper%29> .
//
//     _:e0-93 rdf:type oae:Entity ;
//         oae:confidence       "-2.1636969052308817"^^xsd:double ;
//         oae:detectedAs       "yg" ;
//         oae:position         "7352"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/YG_%28rapper%29> .
//
//     _:e0-94 rdf:type oae:Entity ;
//         oae:confidence       "-2.2703402137733537"^^xsd:double ;
//         oae:detectedAs       "portugal" ;
//         oae:position         "377"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Portugal> .
//
//     _:e0-95 rdf:type oae:Entity ;
//         oae:confidence       "-2.3212551217877317"^^xsd:double ;
//         oae:detectedAs       "dialog" ;
//         oae:position         "7822"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Dialogue> .
//
//     _:e0-96 rdf:type oae:Entity ;
//         oae:confidence       "-2.3313093834462535"^^xsd:double ;
//         oae:detectedAs       "iframe" ;
//         oae:position         "7849"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTML_element> .
//
//     _:e0-97 rdf:type oae:Entity ;
//         oae:confidence       "-2.364970759827518"^^xsd:double ;
//         oae:detectedAs       "i send a message" ;
//         oae:position         "1602"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/I_Send_a_Message> .
//
//     _:e0-98 rdf:type oae:Entity ;
//         oae:confidence       "-2.394631812517905"^^xsd:double ;
//         oae:detectedAs       "us mobile" ;
//         oae:position         "5904"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/U_Mobile> .
//
//     _:e0-99 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "9145"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-100 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7649"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-101 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7547"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-102 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7445"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-103 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7343"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-104 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7241"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-105 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7139"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-106 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "7037"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-107 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6935"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-108 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6833"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-109 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6701"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-110 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6583"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-111 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6479"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-112 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6375"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-113 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6257"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-114 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "6139"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-115 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "10445"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-116 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "10341"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-117 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "10236"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-118 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "10132"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-119 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "10029"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-120 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "9926"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-121 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "9824"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-122 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "9721"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-123 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "9618"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-124 rdf:type oae:Entity ;
//         oae:confidence       "-2.5267816654014794"^^xsd:double ;
//         oae:detectedAs       "faq" ;
//         oae:position         "9515"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/FAQ> .
//
//     _:e0-125 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "10931"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-126 rdf:type oae:Entity ;
//         oae:confidence       "-2.698517868034962"^^xsd:double ;
//         oae:detectedAs       "mobile device" ;
//         oae:position         "2718"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Mobile_device> .
//
//     _:e0-127 rdf:type oae:Entity ;
//         oae:confidence       "-2.698517868034962"^^xsd:double ;
//         oae:detectedAs       "mobile device" ;
//         oae:position         "2560"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Mobile_device> .
//
//     _:e0-128 rdf:type oae:Entity ;
//         oae:confidence       "-2.701124884669759"^^xsd:double ;
//         oae:detectedAs       "push notifications" ;
//         oae:position         "1479"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Apple_Push_Notification_Service> .
//
//     _:e0-129 rdf:type oae:Entity ;
//         oae:confidence       "-2.701124884669759"^^xsd:double ;
//         oae:detectedAs       "push notifications" ;
// ...
//         oae:confidence       "-4.21170359222732"^^xsd:double ;
//         oae:detectedAs       "static" ;
//         oae:position         "6346"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Static_%28DC_Comics%29> .
//
//     _:e0-332 rdf:type oae:Entity ;
//         oae:confidence       "-4.21170359222732"^^xsd:double ;
//         oae:detectedAs       "static" ;
//         oae:position         "6228"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Static_%28DC_Comics%29> .
//
//     _:e0-333 rdf:type oae:Entity ;
//         oae:confidence       "-4.21170359222732"^^xsd:double ;
//         oae:detectedAs       "static" ;
//         oae:position         "6110"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Static_%28DC_Comics%29> .
//
//     _:e0-334 rdf:type oae:Entity ;
//         oae:confidence       "-4.222311278916468"^^xsd:double ;
//         oae:detectedAs       "tab" ;
//         oae:position         "1450"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tab_%28soft_drink%29> .
//
//     _:e0-335 rdf:type oae:Entity ;
//         oae:confidence       "-4.222311278916468"^^xsd:double ;
//         oae:detectedAs       "tab" ;
//         oae:position         "1417"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tab_%28soft_drink%29> .
//
//     _:e0-336 rdf:type oae:Entity ;
//         oae:confidence       "-4.222311278916468"^^xsd:double ;
//         oae:detectedAs       "tab" ;
//         oae:position         "1290"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tab_%28soft_drink%29> .
//
//     _:e0-337 rdf:type oae:Entity ;
//         oae:confidence       "-4.222311278916468"^^xsd:double ;
//         oae:detectedAs       "tab" ;
//         oae:position         "1258"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tab_%28soft_drink%29> .
//
//     _:e0-338 rdf:type oae:Entity ;
//         oae:confidence       "-4.24333601369431"^^xsd:double ;
//         oae:detectedAs       "what s new" ;
//         oae:position         "950"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/What%27s_New%3F> .
//
//     _:e0-339 rdf:type oae:Entity ;
//         oae:confidence       "-4.260350205810985"^^xsd:double ;
//         oae:detectedAs       "yf" ;
//         oae:position         "7556"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Northrop_YF-23> .
//
//     _:e0-340 rdf:type oae:Entity ;
//         oae:confidence       "-4.2634751288959265"^^xsd:double ;
//         oae:detectedAs       "the list" ;
//         oae:position         "5794"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_List_%282007_film%29> .
//
//     _:e0-341 rdf:type oae:Entity ;
//         oae:confidence       "-4.340508115096026"^^xsd:double ;
//         oae:detectedAs       "messages" ;
//         oae:position         "2066"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Message> .
//
//     _:e0-342 rdf:type oae:Entity ;
//         oae:confidence       "-4.340508115096026"^^xsd:double ;
//         oae:detectedAs       "messages" ;
//         oae:position         "1850"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Message> .
//
//     _:e0-343 rdf:type oae:Entity ;
//         oae:confidence       "-4.365191631263215"^^xsd:double ;
//         oae:detectedAs       "time frame" ;
//         oae:position         "3492"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Era> .
//
//     _:e0-344 rdf:type oae:Entity ;
//         oae:confidence       "-4.372203391918539"^^xsd:double ;
//         oae:detectedAs       "help" ;
//         oae:position         "10965"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Help%21_%28album%29> .
//
//     _:e0-345 rdf:type oae:Entity ;
//         oae:confidence       "-4.372203391918539"^^xsd:double ;
//         oae:detectedAs       "help" ;
//         oae:position         "9133"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Help%21_%28album%29> .
//
//     _:e0-346 rdf:type oae:Entity ;
//         oae:confidence       "-4.372203391918539"^^xsd:double ;
//         oae:detectedAs       "help" ;
//         oae:position         "6037"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Help%21_%28album%29> .
//
//     _:e0-347 rdf:type oae:Entity ;
//         oae:confidence       "-4.372203391918539"^^xsd:double ;
//         oae:detectedAs       "help" ;
//         oae:position         "0"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Help%21_%28album%29> .
//
//     _:e0-348 rdf:type oae:Entity ;
//         oae:confidence       "-4.384920740857638"^^xsd:double ;
//         oae:detectedAs       "photo" ;
//         oae:position         "8298"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Photograph> .
//
//     _:e0-349 rdf:type oae:Entity ;
//         oae:confidence       "-4.399157103658479"^^xsd:double ;
//         oae:detectedAs       "permanent" ;
//         oae:position         "6640"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permanent> .
//
//     _:e0-350 rdf:type oae:Entity ;
//         oae:confidence       "-4.399157103658479"^^xsd:double ;
//         oae:detectedAs       "permanent" ;
//         oae:position         "6314"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permanent> .
//
//     _:e0-351 rdf:type oae:Entity ;
//         oae:confidence       "-4.399157103658479"^^xsd:double ;
//         oae:detectedAs       "permanent" ;
//         oae:position         "6196"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permanent> .
//
//     _:e0-352 rdf:type oae:Entity ;
//         oae:confidence       "-4.419105753788312"^^xsd:double ;
//         oae:detectedAs       "compose" ;
//         oae:position         "2058"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Compose_key> .
//
//     _:e0-353 rdf:type oae:Entity ;
//         oae:confidence       "-4.427669569057082"^^xsd:double ;
//         oae:detectedAs       "upgrade you" ;
//         oae:position         "638"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Upgrade_U> .
//
//     _:e0-354 rdf:type oae:Entity ;
//         oae:confidence       "-4.49715180062991"^^xsd:double ;
//         oae:detectedAs       "the wall" ;
//         oae:position         "3633"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Wall> .
//
//     _:e0-355 rdf:type oae:Entity ;
//         oae:confidence       "-4.500861523611259"^^xsd:double ;
//         oae:detectedAs       "cookie" ;
//         oae:position         "10834"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTTP_cookie> .
//
//     _:e0-356 rdf:type oae:Entity ;
//         oae:confidence       "-4.5175201739492366"^^xsd:double ;
//         oae:detectedAs       "6k" ;
//         oae:position         "6956"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Form_6K> .
//
//     _:e0-357 rdf:type oae:Entity ;
//         oae:confidence       "-4.532117635055076"^^xsd:double ;
//         oae:detectedAs       "document" ;
//         oae:position         "10825"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Document> .
//
//     _:e0-358 rdf:type oae:Entity ;
//         oae:confidence       "-4.5690377522494625"^^xsd:double ;
//         oae:detectedAs       "share facebook" ;
//         oae:position         "537"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-359 rdf:type oae:Entity ;
//         oae:confidence       "-4.571648562480428"^^xsd:double ;
//         oae:detectedAs       "learn" ;
//         oae:position         "938"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Learning> .
//
//     _:e0-360 rdf:type oae:Entity ;
//         oae:confidence       "-4.571648562480428"^^xsd:double ;
//         oae:detectedAs       "learn" ;
//         oae:position         "780"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Learning> .
//
//     _:e0-361 rdf:type oae:Entity ;
//         oae:confidence       "-4.573211264806663"^^xsd:double ;
//         oae:detectedAs       "ll" ;
//         oae:position         "4771"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Ll> .
//
//     _:e0-362 rdf:type oae:Entity ;
//         oae:confidence       "-4.6013045138923365"^^xsd:double ;
//         oae:detectedAs       "change" ;
//         oae:position         "5604"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Change.org> .
//
//     _:e0-363 rdf:type oae:Entity ;
//         oae:confidence       "-4.6013045138923365"^^xsd:double ;
//         oae:detectedAs       "change" ;
//         oae:position         "5447"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Change.org> .
//
//     _:e0-364 rdf:type oae:Entity ;
//         oae:confidence       "-4.653173466807299"^^xsd:double ;
//         oae:detectedAs       "you re on" ;
//         oae:position         "4164"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/You%27re_On%21> .
//
//     _:e0-365 rdf:type oae:Entity ;
//         oae:confidence       "-4.653173466807299"^^xsd:double ;
//         oae:detectedAs       "you re on" ;
//         oae:position         "4003"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/You%27re_On%21> .
//
//     _:e0-366 rdf:type oae:Entity ;
//         oae:confidence       "-4.6663813701575965"^^xsd:double ;
//         oae:detectedAs       "basics learn" ;
//         oae:position         "29"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Learning_theory_%28education%29> .
//
//     _:e0-367 rdf:type oae:Entity ;
//         oae:confidence       "-4.679640504237585"^^xsd:double ;
//         oae:detectedAs       "button" ;
//         oae:position         "4199"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Button> .
//
//     _:e0-368 rdf:type oae:Entity ;
//         oae:confidence       "-4.679640504237585"^^xsd:double ;
//         oae:detectedAs       "button" ;
//         oae:position         "4038"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Button> .
//
//     _:e0-369 rdf:type oae:Entity ;
//         oae:confidence       "-4.679640504237585"^^xsd:double ;
//         oae:detectedAs       "button" ;
//         oae:position         "1015"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Button> .
//
//     _:e0-370 rdf:type oae:Entity ;
//         oae:confidence       "-4.695845506895522"^^xsd:double ;
//         oae:detectedAs       "yi" ;
//         oae:position         "7454"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Yi_people> .
//
//     _:e0-371 rdf:type oae:Entity ;
//         oae:confidence       "-4.705174260817093"^^xsd:double ;
//         oae:detectedAs       "id" ;
//         oae:position         "9259"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Id%2C_ego_and_super-ego> .
//
//     _:e0-372 rdf:type oae:Entity ;
//         oae:confidence       "-4.742810588429056"^^xsd:double ;
//         oae:detectedAs       "h type" ;
//         oae:position         "7483"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/H_engine> .
//
//     _:e0-373 rdf:type oae:Entity ;
//         oae:confidence       "-4.779680263174529"^^xsd:double ;
//         oae:detectedAs       "e" ;
//         oae:position         "10708"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/E> .
//
//     _:e0-374 rdf:type oae:Entity ;
//         oae:confidence       "-4.8147624042796995"^^xsd:double ;
//         oae:detectedAs       "abuse" ;
//         oae:position         "168"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Abuse> .
//
//     _:e0-375 rdf:type oae:Entity ;
//         oae:confidence       "-4.815807770048514"^^xsd:double ;
//         oae:detectedAs       "behavior" ;
//         oae:position         "8873"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Behavior> .
//
//     _:e0-376 rdf:type oae:Entity ;
//         oae:confidence       "-4.850563971159984"^^xsd:double ;
//         oae:detectedAs       "explore" ;
//         oae:position         "77"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Eplerenone> .
//
//     _:e0-377 rdf:type oae:Entity ;
//         oae:confidence       "-4.861908076555898"^^xsd:double ;
//         oae:detectedAs       "safety" ;
//         oae:position         "222"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Safety> .
//
//     _:e0-378 rdf:type oae:Entity ;
//         oae:confidence       "-4.877905229429996"^^xsd:double ;
//         oae:detectedAs       "popular" ;
//         oae:position         "85"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Popular_%28TV_series%29> .
//
//     _:e0-379 rdf:type oae:Entity ;
//         oae:confidence       "-4.882019139655068"^^xsd:double ;
//         oae:detectedAs       "maybe" ;
//         oae:position         "3388"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Maybe_%28The_Chantels_song%29> .
//
//     _:e0-380 rdf:type oae:Entity ;
//         oae:confidence       "-4.882019139655068"^^xsd:double ;
//         oae:detectedAs       "maybe" ;
//         oae:position         "3230"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Maybe_%28The_Chantels_song%29> .
//
//     _:e0-381 rdf:type oae:Entity ;
//         oae:confidence       "-4.882019139655068"^^xsd:double ;
//         oae:detectedAs       "maybe" ;
//         oae:position         "2666"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Maybe_%28The_Chantels_song%29> .
//
//     _:e0-382 rdf:type oae:Entity ;
//         oae:confidence       "-4.882019139655068"^^xsd:double ;
//         oae:detectedAs       "maybe" ;
//         oae:position         "2508"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Maybe_%28The_Chantels_song%29> .
//
//     _:e0-383 rdf:type oae:Entity ;
//         oae:confidence       "-4.912665338541297"^^xsd:double ;
//         oae:detectedAs       "about advertising" ;
//         oae:position         "5958"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Advertising> .
//
//     _:e0-384 rdf:type oae:Entity ;
//         oae:confidence       "-4.923293052039591"^^xsd:double ;
//         oae:detectedAs       "scroll to" ;
//         oae:position         "2326"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Scroll> .
//
//     _:e0-385 rdf:type oae:Entity ;
//         oae:confidence       "-4.923293052039591"^^xsd:double ;
//         oae:detectedAs       "scroll to" ;
//         oae:position         "2241"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Scroll> .
//
//     _:e0-386 rdf:type oae:Entity ;
//         oae:confidence       "-4.983375860633386"^^xsd:double ;
//         oae:detectedAs       "rotate" ;
//         oae:position         "8360"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Rotation> .
//
//     _:e0-387 rdf:type oae:Entity ;
//         oae:confidence       "-4.986186720461397"^^xsd:double ;
//         oae:detectedAs       "c" ;
//         oae:position         "9002"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/C_%28programming_language%29> .
//
//     _:e0-388 rdf:type oae:Entity ;
//         oae:confidence       "-4.997972863586117"^^xsd:double ;
//         oae:detectedAs       "click" ;
//         oae:position         "4232"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Click_%282006_film%29> .
//
//     _:e0-389 rdf:type oae:Entity ;
//         oae:confidence       "-4.997972863586117"^^xsd:double ;
//         oae:detectedAs       "click" ;
//         oae:position         "4185"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Click_%282006_film%29> .
//
//     _:e0-390 rdf:type oae:Entity ;
//         oae:confidence       "-4.997972863586117"^^xsd:double ;
//         oae:detectedAs       "click" ;
//         oae:position         "4024"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Click_%282006_film%29> .

// %% [markdown]
// # Sort and store with headers

// %%
val headers = TripleHeader.append("oae" -> "http://www.ics.forth.gr/isl/oae/core#")

// %%
val triples = ArchiveSpark2Triples.toStringsSorted(headers, documentTriples, sameAsTriples, versionTriples)

// %%
triples.saveAsTextFile(s"$collection-Triples.gz", classOf[GzipCodec])
