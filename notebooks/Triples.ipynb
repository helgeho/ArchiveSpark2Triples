// %% [markdown]
// This notebook requires FEL4ArchiveSpark: https://github.com/helgeho/FEL4ArchiveSpark

// %%
import de.l3s.archivespark._
import de.l3s.archivespark.implicits._
import de.l3s.archivespark.specific.warc._
import de.l3s.archivespark.specific.warc.specs._
import de.l3s.archivespark.specific.warc.implicits._
import de.l3s.archivespark.enrich._
import de.l3s.archivespark.enrich.functions._
import de.l3s.archivespark.enrich.dataloads._
import de.l3s.archivespark.enrichfunctions.fel._
import de.l3s.archivespark2triples._
import org.apache.hadoop.io.compress.GzipCodec

// %%
sc.setCheckpointDir("spark_checkpoint")

// %% [markdown]
// # Load the FEL model file

// %%
val modelFile = "english-nov15.hash"
sc.addFile("hdfs:///user/holzmann/" + modelFile)

// %% [markdown]
// # Initialize the web archive collection

// %%
val collection = "ArchiveIt-Collection-2950"
val cdxPath = s"/data/archiveit/$collection/cdx/*.cdx.gz"
val warcPath = s"/data/archiveit/$collection/warc"

// %%
val records = ArchiveSpark.load(sc, WarcCdxHdfsSpec(cdxPath, warcPath)).filter(_.compressedSize < 1024 * 100) // 100 kb

// %%
records.peekJson
// Out:
// {
//   "record":{
//     "redirectUrl":"-",
//     "timestamp":"20111222021216",
//     "digest":"ZPP7YDXYWOVKO3RILANIHUPL3REXJDZE",
//     "originalUrl":"http://184.107.185.46/newsbeast/index.php?w=500&h=300&b=http://www.newsbeast.gr/files/1/2011/06/15/sintagma_1_5.jpg",
//     "surtUrl":"46,185,107,184)/newsbeast/index.php?b=http://www.newsbeast.gr/files/1/2011/06/15/sintagma_1_5.jpg&h=300&w=500",
//     "mime":"text/html",
//     "compressedSize":464,
//     "meta":"-",
//     "status":404
//   }
// }

// %% [markdown]
// # Select successful responses of type HTML and detect duplicates

// %%
val responses = records.filter(r => r.status == 200 && r.mime == "text/html")

// %%
val earliestDigests = responses.map(r => ((r.surtUrl, r.digest), r)).reduceByKey{(r1, r2) =>
    if (r1.time < r2.time) r1 else r2
}

// %%
val duplicates = records.map(r => ((r.surtUrl, r.digest), r)).join(earliestDigests).map{case (_, records) => records}.filter{case (r1, r2) => r1.time != r2.time}

// %% [markdown]
// # Generate *ArchivedDocument* triples representing distinct webpages

// %%
val versions = earliestDigests.map{case (_, r) => r}.union(duplicates.map{case (r1, r2) => r1})

// %%
versions.count
// Out:
// 10427385

// %%
val documentTriples = ArchiveSpark2Triples.generateDocs(versions)

// %%
documentTriples.count
// Out:
// 3036326

// %%
println(documentTriples.peek)
// Out:
// <http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest> rdf:type owa:ArchivedDocument ;
//     owa:numOfCaptures    "6"^^xsd:integer ;
//     owa:firstCapture     "2011-12-03T05:56:19"^^xsd:dateTime ;
//     owa:lastCapture      "2012-01-03T03:36:09"^^xsd:dateTime ;
//     dc:hasVersion        <https://web.archive.org/web/20111203055619/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111210061229/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111217055735/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111220030152/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20111227031921/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest>,
//                          <https://web.archive.org/web/20120103033609/http://occupyalabama.org/forum/showthread.php?t=161&goto=nextnewest> .

// %% [markdown]
// # Create "*sameAs* triples" from duplicates

// %%
val sameAsTriples = ArchiveSpark2Triples.generateSameAsVersions(duplicates)

// %%
println(sameAsTriples.peek)
// Out:
// <https://web.archive.org/web/20120105062548/http://www.livestream.com/forum/showpost.php?p=18958&postcount=9> rdf:type owa:VersionedDocument ;
//     dc:date              "2012-01-05T06:25:48"^^xsd:dateTime ;
//     owl:sameAs           <https://web.archive.org/web/20111229064632/http://www.livestream.com/forum/showpost.php?p=18958&postcount=9> .

// %% [markdown]
// # Generate *VersionedDocument* triples with title and entities

// %%
val repartitioned = earliestDigests.map{case (_, r) => r}.repartition(5000)

// %%
val title = HtmlText.of(Html.first("title"))
val responsesWithTitles = repartitioned.enrich(title)

// %%
val fel = FELwithTimeOut(scoreThreshold = -5, modelFile = modelFile).on(HtmlText)
val responsesWithEntities = responsesWithTitles.enrich(fel)

// %%
responsesWithEntities.peekJson
// Out:
// {
//   "record":{
//     "redirectUrl":"-",
//     "timestamp":"20120107181926",
//     "digest":"4HJLCNZLAJH33NLYYUFRHZMTHBKPKGSC",
//     "originalUrl":"https://www.facebook.com/family/Fdez-D%C3%ADaz/aZc/7",
//     "surtUrl":"com,facebook)/family/fdez-d%c3%adaz/azc/7",
//     "mime":"text/html",
//     "compressedSize":6365,
//     "meta":"-",
//     "status":200
//   },
//   "payload":{
//     "string":{
//       "html":{
//         "title":{
//           "text":"Fdez Díaz | Facebook"
//         },
//         "body":{
//           "text":{
//             "entities":[
//               {
//                 "span":"facebook",
//                 "endOffset":717,
//                 "score":-0.35284731226502275,
//                 "annotation":"Facebook",
//                 "startOffset":709
//               },
//               {
//                 "span":"fac...

// %%
val versionTriples = ArchiveSpark2Triples.generateVersionsMapped(responsesWithEntities) {(record, uid, doc) =>
    val recordTitle = record.value(title).getOrElse("")
    val recordEntities = record.value(fel).getOrElse(Seq.empty)
    doc.appendTriples("dc:title", s"""\"recordTitle\"""").appendChildren("schema:mentions", {
        recordEntities.zipWithIndex.map{case (entity, i) => TripleDoc(
            s"_:e$uid-$i",
            "oae:Entity",
            Seq(
                "oae:confidence" -> Seq(s""""${entity.score}"^^xsd:double"""),
                "oae:detectedAs" -> Seq(s"""\"${entity.span}\""""),
                "oae:position" -> Seq(s""""${entity.startOffset}"^^xsd:integer"""),
                "oae:hasMatchedURI" -> Seq(s"<http://dbpedia.org/resource/${entity.annotation}>")
            )
        )}
    })
}

// %%
println(versionTriples.peek)
// Out:
// <https://web.archive.org/web/20120510090242/https://www.facebook.com/permalink.php?story_fbid=331396450236173&id=300935383297289> rdf:type owa:VersionedDocument ;
//     dc:date              "2012-05-10T09:02:42"^^xsd:dateTime ;
//     dc:format            "text/html" ;
//     dc:title             "recordTitle" ;
//     schema:mentions      _:e0-0,
//                          _:e0-1,
//                          _:e0-2,
//                          _:e0-3,
//                          _:e0-4,
//                          _:e0-5,
//                          _:e0-6,
//                          _:e0-7,
//                          _:e0-8,
//                          _:e0-9,
//                          _:e0-10,
//                          _:e0-11,
//                          _:e0-12,
//                          _:e0-13,
//                          _:e0-14,
//                          _:e0-15,
//                          _:e0-16,
//                          _:e0-17,
//                          _:e0-18,
//                          _:e0-19,
//                          _:e0-20,
//                          _:e0-21,
//                          _:e0-22,
//                          _:e0-23,
//                          _:e0-24,
//                          _:e0-25,
//                          _:e0-26,
//                          _:e0-27,
//                          _:e0-28,
//                          _:e0-29,
//                          _:e0-30,
//                          _:e0-31,
//                          _:e0-32,
//                          _:e0-33,
//                          _:e0-34,
//                          _:e0-35,
//                          _:e0-36,
//                          _:e0-37,
//                          _:e0-38,
//                          _:e0-39,
//                          _:e0-40,
//                          _:e0-41,
//                          _:e0-42,
//                          _:e0-43,
//                          _:e0-44,
//                          _:e0-45,
//                          _:e0-46,
//                          _:e0-47,
//                          _:e0-48,
//                          _:e0-49,
//                          _:e0-50,
//                          _:e0-51,
//                          _:e0-52,
//                          _:e0-53,
//                          _:e0-54,
//                          _:e0-55,
//                          _:e0-56,
//                          _:e0-57,
//                          _:e0-58,
//                          _:e0-59,
//                          _:e0-60,
//                          _:e0-61,
//                          _:e0-62,
//                          _:e0-63,
//                          _:e0-64,
//                          _:e0-65,
//                          _:e0-66,
//                          _:e0-67,
//                          _:e0-68,
//                          _:e0-69,
//                          _:e0-70,
//                          _:e0-71,
//                          _:e0-72,
//                          _:e0-73,
//                          _:e0-74,
//                          _:e0-75,
//                          _:e0-76,
//                          _:e0-77,
//                          _:e0-78,
//                          _:e0-79,
//                          _:e0-80,
//                          _:e0-81,
//                          _:e0-82,
//                          _:e0-83,
//                          _:e0-84,
//                          _:e0-85,
//                          _:e0-86,
//                          _:e0-87,
//                          _:e0-88,
//                          _:e0-89,
//                          _:e0-90,
//                          _:e0-91,
//                          _:e0-92,
//                          _:e0-93,
//                          _:e0-94,
//                          _:e0-95,
//                          _:e0-96,
//                          _:e0-97,
//                          _:e0-98,
//                          _:e0-99,
//                          _:e0-100,
//                          _:e0-101,
//                          _:e0-102,
//                          _:e0-103,
//                          _:e0-104,
//                          _:e0-105,
//                          _:e0-106,
//                          _:e0-107,
//                          _:e0-108,
//                          _:e0-109,
//                          _:e0-110,
//                          _:e0-111,
//                          _:e0-112,
//                          _:e0-113,
//                          _:e0-114,
//                          _:e0-115,
//                          _:e0-116,
//                          _:e0-117,
//                          _:e0-118,
//                          _:e0-119,
//                          _:e0-120,
//                          _:e0-121,
//                          _:e0-122,
//                          _:e0-123,
//                          _:e0-124,
//                          _:e0-125,
//                          _:e0-126,
//                          _:e0-127,
//                          _:e0-128,
//                          _:e0-129,
//                          _:e0-130,
//                          _:e0-131,
//                          _:e0-132,
//                          _:e0-133,
//                          _:e0-134,
//                          _:e0-135,
//                          _:e0-136,
//                          _:e0-137,
//                          _:e0-138,
//                          _:e0-139,
//                          _:e0-140,
//                          _:e0-141,
//                          _:e0-142,
//                          _:e0-143,
//                          _:e0-144,
//                          _:e0-145,
//                          _:e0-146,
//                          _:e0-147,
//                          _:e0-148,
//                          _:e0-149,
//                          _:e0-150,
//                          _:e0-151,
//                          _:e0-152,
//                          _:e0-153,
//                          _:e0-154,
//                          _:e0-155,
//                          _:e0-156,
//                          _:e0-157,
//                          _:e0-158,
//                          _:e0-159,
//                          _:e0-160,
//                          _:e0-161,
//                          _:e0-162,
//                          _:e0-163,
//                          _:e0-164,
//                          _:e0-165,
//                          _:e0-166,
//                          _:e0-167,
//                          _:e0-168,
//                          _:e0-169,
//                          _:e0-170,
//                          _:e0-171,
//                          _:e0-172,
//                          _:e0-173,
//                          _:e0-174,
//                          _:e0-175,
//                          _:e0-176,
//                          _:e0-177,
//                          _:e0-178,
//                          _:e0-179,
//                          _:e0-180,
//                          _:e0-181,
//                          _:e0-182,
//                          _:e0-183,
//                          _:e0-184,
//                          _:e0-185,
//                          _:e0-186,
//                          _:e0-187,
//                          _:e0-188,
//                          _:e0-189,
//                          _:e0-190,
//                          _:e0-191,
//                          _:e0-192,
//                          _:e0-193,
//                          _:e0-194,
//                          _:e0-195,
//                          _:e0-196,
//                          _:e0-197,
//                          _:e0-198,
//                          _:e0-199,
//                          _:e0-200,
//                          _:e0-201,
//                          _:e0-202,
//                          _:e0-203,
//                          _:e0-204,
//                          _:e0-205,
//                          _:e0-206,
//                          _:e0-207,
//                          _:e0-208,
//                          _:e0-209,
//                          _:e0-210,
//                          _:e0-211,
//                          _:e0-212,
//                          _:e0-213,
//                          _:e0-214,
//                          _:e0-215,
//                          _:e0-216,
//                          _:e0-217,
//                          _:e0-218,
//                          _:e0-219,
//                          _:e0-220,
//                          _:e0-221,
//                          _:e0-222,
//                          _:e0-223,
//                          _:e0-224,
//                          _:e0-225,
//                          _:e0-226,
//                          _:e0-227,
//                          _:e0-228,
//                          _:e0-229,
//                          _:e0-230,
//                          _:e0-231,
//                          _:e0-232,
//                          _:e0-233,
//                          _:e0-234,
//                          _:e0-235,
//                          _:e0-236,
//                          _:e0-237,
//                          _:e0-238,
//                          _:e0-239,
//                          _:e0-240,
//                          _:e0-241,
//                          _:e0-242,
//                          _:e0-243,
//                          _:e0-244,
//                          _:e0-245,
//                          _:e0-246,
//                          _:e0-247,
//                          _:e0-248,
//                          _:e0-249,
//                          _:e0-250,
//                          _:e0-251,
//                          _:e0-252,
//                          _:e0-253,
//                          _:e0-254,
//                          _:e0-255,
//                          _:e0-256,
//                          _:e0-257,
//                          _:e0-258,
//                          _:e0-259,
//                          _:e0-260,
//                          _:e0-261,
//                          _:e0-262,
//                          _:e0-263,
//                          _:e0-264,
//                          _:e0-265,
//                          _:e0-266,
//                          _:e0-267,
//                          _:e0-268,
//                          _:e0-269,
//                          _:e0-270,
//                          _:e0-271,
//                          _:e0-272,
//                          _:e0-273,
//                          _:e0-274,
//                          _:e0-275,
//                          _:e0-276,
//                          _:e0-277,
//                          _:e0-278,
//                          _:e0-279,
//                          _:e0-280,
//                          _:e0-281,
//                          _:e0-282,
//                          _:e0-283,
//                          _:e0-284,
//                          _:e0-285,
//                          _:e0-286,
//                          _:e0-287,
//                          _:e0-288,
//                          _:e0-289,
//                          _:e0-290,
//                          _:e0-291,
//                          _:e0-292,
//                          _:e0-293,
//                          _:e0-294,
//                          _:e0-295,
//                          _:e0-296,
//                          _:e0-297,
//                          _:e0-298,
//                          _:e0-299,
//                          _:e0-300,
//                          _:e0-301,
//                          _:e0-302,
//                          _:e0-303,
//                          _:e0-304,
//                          _:e0-305,
//                          _:e0-306,
//                          _:e0-307,
//                          _:e0-308,
//                          _:e0-309,
//                          _:e0-310,
//                          _:e0-311,
//                          _:e0-312,
//                          _:e0-313,
//                          _:e0-314,
//                          _:e0-315,
//                          _:e0-316,
//                          _:e0-317,
//                          _:e0-318,
//                          _:e0-319,
//                          _:e0-320,
//                          _:e0-321,
//                          _:e0-322,
//                          _:e0-323,
//                          _:e0-324,
//                          _:e0-325,
//                          _:e0-326,
//                          _:e0-327,
//                          _:e0-328,
//                          _:e0-329,
//                          _:e0-330,
//                          _:e0-331,
//                          _:e0-332,
//                          _:e0-333,
//                          _:e0-334,
//                          _:e0-335,
//                          _:e0-336,
//                          _:e0-337,
//                          _:e0-338,
//                          _:e0-339,
//                          _:e0-340,
//                          _:e0-341,
//                          _:e0-342,
//                          _:e0-343,
//                          _:e0-344,
//                          _:e0-345,
//                          _:e0-346,
//                          _:e0-347,
//                          _:e0-348,
//                          _:e0-349,
//                          _:e0-350,
//                          _:e0-351,
//                          _:e0-352,
//                          _:e0-353,
//                          _:e0-354,
//                          _:e0-355,
//                          _:e0-356,
//                          _:e0-357,
//                          _:e0-358,
//                          _:e0-359,
//                          _:e0-360,
//                          _:e0-361,
//                          _:e0-362,
//                          _:e0-363,
//                          _:e0-364,
//                          _:e0-365,
//                          _:e0-366,
//                          _:e0-367,
//                          _:e0-368,
//                          _:e0-369,
//                          _:e0-370,
//                          _:e0-371,
//                          _:e0-372,
//                          _:e0-373,
//                          _:e0-374,
//                          _:e0-375,
//                          _:e0-376,
//                          _:e0-377,
//                          _:e0-378,
//                          _:e0-379,
//                          _:e0-380,
//                          _:e0-381,
//                          _:e0-382,
//                          _:e0-383,
//                          _:e0-384,
//                          _:e0-385,
//                          _:e0-386,
//                          _:e0-387,
//                          _:e0-388,
//                          _:e0-389,
//                          _:e0-390,
//                          _:e0-391,
//                          _:e0-392,
//                          _:e0-393,
//                          _:e0-394,
//                          _:e0-395,
//                          _:e0-396,
//                          _:e0-397,
//                          _:e0-398,
//                          _:e0-399,
//                          _:e0-400,
//                          _:e0-401,
//                          _:e0-402 .
//
//     _:e0-0 rdf:type oae:Entity ;
//         oae:confidence       "-2.875843080958637"^^xsd:double ;
//         oae:detectedAs       "email" ;
//         oae:position         "0"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Email> .
//
//     _:e0-1 rdf:type oae:Entity ;
//         oae:confidence       "-3.293898228478974"^^xsd:double ;
//         oae:detectedAs       "password" ;
//         oae:position         "45"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Password> .
//
//     _:e0-2 rdf:type oae:Entity ;
//         oae:confidence       "-3.293898228478974"^^xsd:double ;
//         oae:detectedAs       "password" ;
//         oae:position         "6"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Password> .
//
//     _:e0-3 rdf:type oae:Entity ;
//         oae:confidence       "-3.55185790536142"^^xsd:double ;
//         oae:detectedAs       "connect" ;
//         oae:position         "82"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Cone_beam_computed_tomography> .
//
//     _:e0-4 rdf:type oae:Entity ;
//         oae:confidence       "-4.167296551030673"^^xsd:double ;
//         oae:detectedAs       "up facebook" ;
//         oae:position         "60"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-5 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "130"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-6 rdf:type oae:Entity ;
//         oae:confidence       "-2.1107986234374096"^^xsd:double ;
//         oae:detectedAs       "jib" ;
//         oae:position         "184"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Jib> .
//
//     _:e0-7 rdf:type oae:Entity ;
//         oae:confidence       "-2.9055758137176935"^^xsd:double ;
//         oae:detectedAs       "s s" ;
//         oae:position         "188"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/S> .
//
//     _:e0-8 rdf:type oae:Entity ;
//         oae:confidence       "-3.6863109904734306"^^xsd:double ;
//         oae:detectedAs       "english" ;
//         oae:position         "146"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/English_language> .
//
//     _:e0-9 rdf:type oae:Entity ;
//         oae:confidence       "-3.7438567631100406"^^xsd:double ;
//         oae:detectedAs       "2012" ;
//         oae:position         "141"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/2012_%28film%29> .
//
//     _:e0-10 rdf:type oae:Entity ;
//         oae:confidence       "-0.8493495210884041"^^xsd:double ;
//         oae:detectedAs       "bambuser" ;
//         oae:position         "388"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Bambuser> .
//
//     _:e0-11 rdf:type oae:Entity ;
//         oae:confidence       "-0.8493495210884041"^^xsd:double ;
//         oae:detectedAs       "bambuser" ;
//         oae:position         "287"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Bambuser> .
//
//     _:e0-12 rdf:type oae:Entity ;
//         oae:confidence       "-1.1484119342655124"^^xsd:double ;
//         oae:detectedAs       "occ" ;
//         oae:position         "384"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Orange_County_Choppers> .
//
//     _:e0-13 rdf:type oae:Entity ;
//         oae:confidence       "-2.4492760273612526"^^xsd:double ;
//         oae:detectedAs       "18" ;
//         oae:position         "252"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/18_%28number%29> .
//
//     _:e0-14 rdf:type oae:Entity ;
//         oae:confidence       "-2.954742403898369"^^xsd:double ;
//         oae:detectedAs       "tous" ;
//         oae:position         "219"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Tous%2C_Valencia> .
//
//     _:e0-15 rdf:type oae:Entity ;
//         oae:confidence       "-3.2483800480974727"^^xsd:double ;
//         oae:detectedAs       "paris" ;
//         oae:position         "298"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Paris> .
//
//     _:e0-16 rdf:type oae:Entity ;
//         oae:confidence       "-3.4859754444500686"^^xsd:double ;
//         oae:detectedAs       "february 19" ;
//         oae:position         "263"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/February_19> .
//
//     _:e0-17 rdf:type oae:Entity ;
//         oae:confidence       "-3.8150963703478196"^^xsd:double ;
//         oae:detectedAs       "stream" ;
//         oae:position         "375"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Stream> .
//
//     _:e0-18 rdf:type oae:Entity ;
//         oae:confidence       "-3.883201005361731"^^xsd:double ;
//         oae:detectedAs       "au" ;
//         oae:position         "372"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Astronomical_unit> .
//
//     _:e0-19 rdf:type oae:Entity ;
//         oae:confidence       "-4.240102807984832"^^xsd:double ;
//         oae:detectedAs       "delf" ;
//         oae:position         "367"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Dipl%C3%B4me_d%27%C3%A9tudes_en_langue_fran%C3%A7aise> .
//
//     _:e0-20 rdf:type oae:Entity ;
//         oae:confidence       "-4.561934211754259"^^xsd:double ;
//         oae:detectedAs       "des" ;
//         oae:position         "224"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Diethylstilbestrol> .
//
//     _:e0-21 rdf:type oae:Entity ;
//         oae:confidence       "-4.63887251504799"^^xsd:double ;
//         oae:detectedAs       "nous sommes" ;
//         oae:position         "207"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/French_conjugation> .
//
//     _:e0-22 rdf:type oae:Entity ;
//         oae:confidence       "-0.8493495210884041"^^xsd:double ;
//         oae:detectedAs       "bambuser" ;
//         oae:position         "435"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Bambuser> .
//
//     _:e0-23 rdf:type oae:Entity ;
//         oae:confidence       "-4.119188497345012"^^xsd:double ;
//         oae:detectedAs       "live broadcast" ;
//         oae:position         "401"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Live_television> .
//
//     _:e0-24 rdf:type oae:Entity ;
//         oae:confidence       "-2.3671858622824886"^^xsd:double ;
//         oae:detectedAs       "graikos" ;
//         oae:position         "475"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Graikos> .
//
//     _:e0-25 rdf:type oae:Entity ;
//         oae:confidence       "-2.672872324012155"^^xsd:double ;
//         oae:detectedAs       "chatelais" ;
//         oae:position         "455"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Ch%C3%A2telais> .
//
//     _:e0-26 rdf:type oae:Entity ;
//         oae:confidence       "-2.672872324012155"^^xsd:double ;
//         oae:detectedAs       "chatelais" ;
//         oae:position         "501"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Ch%C3%A2telais> .
//
//     _:e0-27 rdf:type oae:Entity ;
//         oae:confidence       "-2.8197568968461604"^^xsd:double ;
//         oae:detectedAs       "est" ;
//         oae:position         "561"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Eastern_Time_Zone> .
//
//     _:e0-28 rdf:type oae:Entity ;
//         oae:confidence       "-2.8197568968461604"^^xsd:double ;
//         oae:detectedAs       "est" ;
//         oae:position         "519"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Eastern_Time_Zone> .
//
//     _:e0-29 rdf:type oae:Entity ;
//         oae:confidence       "-4.210015490756475"^^xsd:double ;
//         oae:detectedAs       "l" ;
//         oae:position         "511"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/L> .
//
//     _:e0-30 rdf:type oae:Entity ;
//         oae:confidence       "-4.561934211754259"^^xsd:double ;
//         oae:detectedAs       "des" ;
//         oae:position         "535"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Diethylstilbestrol> .
//
//     _:e0-31 rdf:type oae:Entity ;
//         oae:confidence       "-4.663761762824985"^^xsd:double ;
//         oae:detectedAs       "appel" ;
//         oae:position         "568"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Jayne_Appel> .
//
//     _:e0-32 rdf:type oae:Entity ;
//         oae:confidence       "-4.776457002406191"^^xsd:double ;
//         oae:detectedAs       "internationale" ;
//         oae:position         "590"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/The_Internationale> .
//
//     _:e0-33 rdf:type oae:Entity ;
//         oae:confidence       "-4.798616857257009"^^xsd:double ;
//         oae:detectedAs       "info" ;
//         oae:position         "549"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/.info> .
//
//     _:e0-34 rdf:type oae:Entity ;
//         oae:confidence       "-2.8734080434808518"^^xsd:double ;
//         oae:detectedAs       "nous" ;
//         oae:position         "627"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Nous> .
//
//     _:e0-35 rdf:type oae:Entity ;
//         oae:confidence       "-4.833777775185451"^^xsd:double ;
//         oae:detectedAs       "la 3" ;
//         oae:position         "606"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Wallops_Flight_Facility_Launch_Area_3> .
//
//     _:e0-36 rdf:type oae:Entity ;
//         oae:confidence       "-1.9856937516063433"^^xsd:double ;
//         oae:detectedAs       "info please" ;
//         oae:position         "806"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Information_Please> .
//
//     _:e0-37 rdf:type oae:Entity ;
//         oae:confidence       "-2.8734080434808518"^^xsd:double ;
//         oae:detectedAs       "nous" ;
//         oae:position         "790"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Nous> .
//
//     _:e0-38 rdf:type oae:Entity ;
//         oae:confidence       "-4.210015490756475"^^xsd:double ;
//         oae:detectedAs       "l" ;
//         oae:position         "804"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/L> .
//
//     _:e0-39 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "818"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-40 rdf:type oae:Entity ;
//         oae:confidence       "-1.946088340662801"^^xsd:double ;
//         oae:detectedAs       "12pm" ;
//         oae:position         "886"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/12-hour_clock> .
//
//     _:e0-41 rdf:type oae:Entity ;
//         oae:confidence       "-2.905906675195366"^^xsd:double ;
//         oae:detectedAs       "97" ;
//         oae:position         "852"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/97_%28number%29> .
//
//     _:e0-42 rdf:type oae:Entity ;
//         oae:confidence       "-3.140304120829511"^^xsd:double ;
//         oae:detectedAs       "fr" ;
//         oae:position         "846"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/.fr> .
//
//     _:e0-43 rdf:type oae:Entity ;
//         oae:confidence       "-3.4859754444500686"^^xsd:double ;
//         oae:detectedAs       "february 19" ;
//         oae:position         "868"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/February_19> .
//
//     _:e0-44 rdf:type oae:Entity ;
//         oae:confidence       "-4.358377213567242"^^xsd:double ;
//         oae:detectedAs       "p" ;
//         oae:position         "850"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/P> .
//
//     _:e0-45 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "995"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-46 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "987"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-47 rdf:type oae:Entity ;
//         oae:confidence       "-4.241596413576523"^^xsd:double ;
//         oae:detectedAs       "5" ;
//         oae:position         "984"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/5> .
//
//     _:e0-48 rdf:type oae:Entity ;
//         oae:confidence       "-4.241596413576523"^^xsd:double ;
//         oae:detectedAs       "5" ;
//         oae:position         "950"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/5> .
//
//     _:e0-49 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "1002"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-50 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "1015"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-51 rdf:type oae:Entity ;
//         oae:confidence       "-1.2887856212557103"^^xsd:double ;
//         oae:detectedAs       "discover" ;
//         oae:position         "1063"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Discover_Card> .
//
//     _:e0-52 rdf:type oae:Entity ;
//         oae:confidence       "-2.7584426100594928"^^xsd:double ;
//         oae:detectedAs       "blog" ;
//         oae:position         "1057"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Blog> .
//
//     _:e0-53 rdf:type oae:Entity ;
//         oae:confidence       "-4.280710037863869"^^xsd:double ;
//         oae:detectedAs       "com facebook" ;
//         oae:position         "1024"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-54 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "1167"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-55 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "1221"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-56 rdf:type oae:Entity ;
//         oae:confidence       "-3.121686277169388"^^xsd:double ;
//         oae:detectedAs       "ctor" ;
//         oae:position         "1123"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Constructor_%28object-oriented_programming%29> .
//
//     _:e0-57 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1172"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-58 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1150"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-59 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1213"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-60 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1180"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-61 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "1228"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-62 rdf:type oae:Entity ;
//         oae:confidence       "-4.874474794901486"^^xsd:double ;
//         oae:detectedAs       "m" ;
//         oae:position         "1133"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/M> .
//
//     _:e0-63 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "1241"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-64 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "1273"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-65 rdf:type oae:Entity ;
//         oae:confidence       "-2.842569569296362"^^xsd:double ;
//         oae:detectedAs       "pflo" ;
//         oae:position         "1287"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Popular_Front_for_the_Liberation_of_Oman> .
//
//     _:e0-66 rdf:type oae:Entity ;
//         oae:confidence       "-3.0248997552309524"^^xsd:double ;
//         oae:detectedAs       "extra" ;
//         oae:position         "1317"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Extra_%28TV_program%29> .
//
//     _:e0-67 rdf:type oae:Entity ;
//         oae:confidence       "-3.6321429120019055"^^xsd:double ;
//         oae:detectedAs       "advertise" ;
//         oae:position         "1340"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Advertising> .
//
//     _:e0-68 rdf:type oae:Entity ;
//         oae:confidence       "-4.009376710352946"^^xsd:double ;
//         oae:detectedAs       "1" ;
//         oae:position         "1323"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/1> .
//
//     _:e0-69 rdf:type oae:Entity ;
//         oae:confidence       "-4.705174260817093"^^xsd:double ;
//         oae:detectedAs       "id" ;
//         oae:position         "1301"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Id%2C_ego_and_super-ego> .
//
//     _:e0-70 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "1415"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-71 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "1475"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-72 rdf:type oae:Entity ;
//         oae:confidence       "-3.121686277169388"^^xsd:double ;
//         oae:detectedAs       "ctor" ;
//         oae:position         "1365"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Constructor_%28object-oriented_programming%29> .
//
//     _:e0-73 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1420"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-74 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1392"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-75 rdf:type oae:Entity ;
//         oae:confidence       "-3.735860721026471"^^xsd:double ;
//         oae:detectedAs       "advertising" ;
//         oae:position         "1442"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Advertising> .
//
//     _:e0-76 rdf:type oae:Entity ;
//         oae:confidence       "-3.735860721026471"^^xsd:double ;
//         oae:detectedAs       "advertising" ;
//         oae:position         "1401"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Advertising> .
//
//     _:e0-77 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1467"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-78 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1428"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-79 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "1482"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-80 rdf:type oae:Entity ;
//         oae:confidence       "-4.874474794901486"^^xsd:double ;
//         oae:detectedAs       "m" ;
//         oae:position         "1375"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/M> .
//
//     _:e0-81 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "1495"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-82 rdf:type oae:Entity ;
//         oae:confidence       "-3.0096895616570416"^^xsd:double ;
//         oae:detectedAs       "careers" ;
//         oae:position         "1509"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Career> .
//
//     _:e0-83 rdf:type oae:Entity ;
//         oae:confidence       "-3.559753349403581"^^xsd:double ;
//         oae:detectedAs       "awesome" ;
//         oae:position         "1570"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/%22Awesome%22> .
//
//     _:e0-84 rdf:type oae:Entity ;
//         oae:confidence       "-4.5151109907374165"^^xsd:double ;
//         oae:detectedAs       "career" ;
//         oae:position         "1551"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Career> .
//
//     _:e0-85 rdf:type oae:Entity ;
//         oae:confidence       "-4.974079387931689"^^xsd:double ;
//         oae:detectedAs       "pf" ;
//         oae:position         "1523"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Power_forward_%28basketball%29> .
//
//     _:e0-86 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "1635"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-87 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "1691"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-88 rdf:type oae:Entity ;
//         oae:confidence       "-3.0096895616570416"^^xsd:double ;
//         oae:detectedAs       "careers" ;
//         oae:position         "1662"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Career> .
//
//     _:e0-89 rdf:type oae:Entity ;
//         oae:confidence       "-3.0096895616570416"^^xsd:double ;
//         oae:detectedAs       "careers" ;
//         oae:position         "1625"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Career> .
//
//     _:e0-90 rdf:type oae:Entity ;
//         oae:confidence       "-3.121686277169388"^^xsd:double ;
//         oae:detectedAs       "ctor" ;
//         oae:position         "1589"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Constructor_%28object-oriented_programming%29> .
//
//     _:e0-91 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1640"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-92 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1616"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-93 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1683"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-94 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1648"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-95 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "1698"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-96 rdf:type oae:Entity ;
//         oae:confidence       "-4.874474794901486"^^xsd:double ;
//         oae:detectedAs       "m" ;
//         oae:position         "1599"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/M> .
//
//     _:e0-97 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "1711"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-98 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "1841"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-99 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "1739"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-100 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "1903"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-101 rdf:type oae:Entity ;
//         oae:confidence       "-3.121686277169388"^^xsd:double ;
//         oae:detectedAs       "ctor" ;
//         oae:position         "1789"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Constructor_%28object-oriented_programming%29> .
//
//     _:e0-102 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1846"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-103 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "1816"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-104 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1895"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-105 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "1854"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-106 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "1910"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-107 rdf:type oae:Entity ;
//         oae:confidence       "-4.874474794901486"^^xsd:double ;
//         oae:detectedAs       "m" ;
//         oae:position         "1799"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/M> .
//
//     _:e0-108 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "1930"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-109 rdf:type oae:Entity ;
//         oae:confidence       "-4.974079387931689"^^xsd:double ;
//         oae:detectedAs       "pf" ;
//         oae:position         "1949"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Power_forward_%28basketball%29> .
//
//     _:e0-110 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "2038"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-111 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "2097"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-112 rdf:type oae:Entity ;
//         oae:confidence       "-3.121686277169388"^^xsd:double ;
//         oae:detectedAs       "ctor" ;
//         oae:position         "1989"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Constructor_%28object-oriented_programming%29> .
//
//     _:e0-113 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "2043"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-114 rdf:type oae:Entity ;
//         oae:confidence       "-3.203588405272618"^^xsd:double ;
//         oae:detectedAs       "markup" ;
//         oae:position         "2016"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Markup_%28business%29> .
//
//     _:e0-115 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "2089"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-116 rdf:type oae:Entity ;
//         oae:confidence       "-4.203931368480851"^^xsd:double ;
//         oae:detectedAs       "null" ;
//         oae:position         "2051"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Null_%28SQL%29> .
//
//     _:e0-117 rdf:type oae:Entity ;
//         oae:confidence       "-4.446693911095304"^^xsd:double ;
//         oae:detectedAs       "http" ;
//         oae:position         "2104"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hypertext_Transfer_Protocol> .
//
//     _:e0-118 rdf:type oae:Entity ;
//         oae:confidence       "-4.874474794901486"^^xsd:double ;
//         oae:detectedAs       "m" ;
//         oae:position         "1999"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/M> .
//
//     _:e0-119 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "2117"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-120 rdf:type oae:Entity ;
//         oae:confidence       "-4.372203391918539"^^xsd:double ;
//         oae:detectedAs       "help" ;
//         oae:position         "2165"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Help%21_%28album%29> .
//
//     _:e0-121 rdf:type oae:Entity ;
//         oae:confidence       "-4.372203391918539"^^xsd:double ;
//         oae:detectedAs       "help" ;
//         oae:position         "2131"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Help%21_%28album%29> .
//
//     _:e0-122 rdf:type oae:Entity ;
//         oae:confidence       "-4.974079387931689"^^xsd:double ;
//         oae:detectedAs       "pf" ;
//         oae:position         "2142"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Power_forward_%28basketball%29> .
//
//     _:e0-123 rdf:type oae:Entity ;
//         oae:confidence       "-1.1435567189784313"^^xsd:double ;
//         oae:detectedAs       "popover" ;
//         oae:position         "2427"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Popover> .
//
//     _:e0-124 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "3218"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-125 rdf:type oae:Entity ;
//         oae:confidence       "-2.145073700637374"^^xsd:double ;
//         oae:detectedAs       "icon" ;
//         oae:position         "2223"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Icon> .
//
//     _:e0-126 rdf:type oae:Entity ;
//         oae:confidence       "-2.884427567041857"^^xsd:double ;
//         oae:detectedAs       "init" ;
//         oae:position         "3080"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Init> .
//
// ...
//
//     _:e0-343 rdf:type oae:Entity ;
//         oae:confidence       "-2.9765887730558096"^^xsd:double ;
//         oae:detectedAs       "scrubber" ;
//         oae:position         "7549"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Scrubber> .
//
//     _:e0-344 rdf:type oae:Entity ;
//         oae:confidence       "-3.7490385063821283"^^xsd:double ;
//         oae:detectedAs       "timeline" ;
//         oae:position         "7530"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Timeline> .
//
//     _:e0-345 rdf:type oae:Entity ;
//         oae:confidence       "-4.009376710352946"^^xsd:double ;
//         oae:detectedAs       "1" ;
//         oae:position         "7655"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/1> .
//
//     _:e0-346 rdf:type oae:Entity ;
//         oae:confidence       "-4.705174260817093"^^xsd:double ;
//         oae:detectedAs       "id" ;
//         oae:position         "7628"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Id%2C_ego_and_super-ego> .
//
//     _:e0-347 rdf:type oae:Entity ;
//         oae:confidence       "-4.705174260817093"^^xsd:double ;
//         oae:detectedAs       "id" ;
//         oae:position         "7588"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Id%2C_ego_and_super-ego> .
//
//     _:e0-348 rdf:type oae:Entity ;
//         oae:confidence       "-4.705174260817093"^^xsd:double ;
//         oae:detectedAs       "id" ;
//         oae:position         "7544"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Id%2C_ego_and_super-ego> .
//
//     _:e0-349 rdf:type oae:Entity ;
//         oae:confidence       "-4.843268443480053"^^xsd:double ;
//         oae:detectedAs       "ns" ;
//         oae:position         "7525"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Nova_Scotia> .
//
//     _:e0-350 rdf:type oae:Entity ;
//         oae:confidence       "-4.946017109713125"^^xsd:double ;
//         oae:detectedAs       "groups" ;
//         oae:position         "7616"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Group_%28mathematics%29> .
//
//     _:e0-351 rdf:type oae:Entity ;
//         oae:confidence       "-0.860123826836972"^^xsd:double ;
//         oae:detectedAs       "arbiter" ;
//         oae:position         "7730"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Arbiter_%28Halo%29> .
//
//     _:e0-352 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "7707"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-353 rdf:type oae:Entity ;
//         oae:confidence       "-4.393934790836252"^^xsd:double ;
//         oae:detectedAs       "persistent" ;
//         oae:position         "7677"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Persistence_%28computer_science%29> .
//
//     _:e0-354 rdf:type oae:Entity ;
//         oae:confidence       "-4.815807770048514"^^xsd:double ;
//         oae:detectedAs       "behavior" ;
//         oae:position         "7668"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Behavior> .
//
//     _:e0-355 rdf:type oae:Entity ;
//         oae:confidence       "-0.860123826836972"^^xsd:double ;
//         oae:detectedAs       "arbiter" ;
//         oae:position         "7778"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Arbiter_%28Halo%29> .
//
//     _:e0-356 rdf:type oae:Entity ;
//         oae:confidence       "-3.485964189310022"^^xsd:double ;
//         oae:detectedAs       "enable" ;
//         oae:position         "7757"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Enabling> .
//
//     _:e0-357 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "7826"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-358 rdf:type oae:Entity ;
//         oae:confidence       "-4.393934790836252"^^xsd:double ;
//         oae:detectedAs       "persistent" ;
//         oae:position         "7795"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Persistence_%28computer_science%29> .
//
//     _:e0-359 rdf:type oae:Entity ;
//         oae:confidence       "-4.815807770048514"^^xsd:double ;
//         oae:detectedAs       "behavior" ;
//         oae:position         "7786"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Behavior> .
//
//     _:e0-360 rdf:type oae:Entity ;
//         oae:confidence       "-2.8479295297369953"^^xsd:double ;
//         oae:detectedAs       "meta" ;
//         oae:position         "7881"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Meta> .
//
//     _:e0-361 rdf:type oae:Entity ;
//         oae:confidence       "-3.474513776512938"^^xsd:double ;
//         oae:detectedAs       "locale" ;
//         oae:position         "7861"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Locale> .
//
//     _:e0-362 rdf:type oae:Entity ;
//         oae:confidence       "-3.4344005227249177"^^xsd:double ;
//         oae:detectedAs       "patterns" ;
//         oae:position         "7944"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Pattern> .
//
//     _:e0-363 rdf:type oae:Entity ;
//         oae:confidence       "-0.7706338807359006"^^xsd:double ;
//         oae:detectedAs       "javascript" ;
//         oae:position         "8194"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-364 rdf:type oae:Entity ;
//         oae:confidence       "-2.7762040960275227"^^xsd:double ;
//         oae:detectedAs       "mb" ;
//         oae:position         "8132"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Megabyte> .
//
//     _:e0-365 rdf:type oae:Entity ;
//         oae:confidence       "-2.7762040960275227"^^xsd:double ;
//         oae:detectedAs       "mb" ;
//         oae:position         "8052"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Megabyte> .
//
//     _:e0-366 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8227"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-367 rdf:type oae:Entity ;
//         oae:confidence       "-3.975021178342929"^^xsd:double ;
//         oae:detectedAs       "3" ;
//         oae:position         "8015"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/3> .
//
//     _:e0-368 rdf:type oae:Entity ;
//         oae:confidence       "-4.009376710352946"^^xsd:double ;
//         oae:detectedAs       "1" ;
//         oae:position         "8155"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/1> .
//
//     _:e0-369 rdf:type oae:Entity ;
//         oae:confidence       "-4.009376710352946"^^xsd:double ;
//         oae:detectedAs       "1" ;
//         oae:position         "8075"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/1> .
//
//     _:e0-370 rdf:type oae:Entity ;
//         oae:confidence       "-4.009376710352946"^^xsd:double ;
//         oae:detectedAs       "1" ;
//         oae:position         "8004"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/1> .
//
//     _:e0-371 rdf:type oae:Entity ;
//         oae:confidence       "-4.532117635055076"^^xsd:double ;
//         oae:detectedAs       "document" ;
//         oae:position         "8250"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Document> .
//
//     _:e0-372 rdf:type oae:Entity ;
//         oae:confidence       "-4.779680263174529"^^xsd:double ;
//         oae:detectedAs       "e" ;
//         oae:position         "8128"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/E> .
//
//     _:e0-373 rdf:type oae:Entity ;
//         oae:confidence       "-4.779680263174529"^^xsd:double ;
//         oae:detectedAs       "e" ;
//         oae:position         "8048"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/E> .
//
//     _:e0-374 rdf:type oae:Entity ;
//         oae:confidence       "-3.524669596635413"^^xsd:double ;
//         oae:detectedAs       "path" ;
//         oae:position         "8278"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Path_%28social_network%29> .
//
//     _:e0-375 rdf:type oae:Entity ;
//         oae:confidence       "-4.500861523611259"^^xsd:double ;
//         oae:detectedAs       "cookie" ;
//         oae:position         "8259"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/HTTP_cookie> .
//
//     _:e0-376 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "8295"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-377 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8328"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-378 rdf:type oae:Entity ;
//         oae:confidence       "-2.579915562414334"^^xsd:double ;
//         oae:detectedAs       "href" ;
//         oae:position         "8367"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Hyperlink> .
//
//     _:e0-379 rdf:type oae:Entity ;
//         oae:confidence       "-0.35284731226502275"^^xsd:double ;
//         oae:detectedAs       "facebook" ;
//         oae:position         "8387"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Facebook> .
//
//     _:e0-380 rdf:type oae:Entity ;
//         oae:confidence       "-1.4604154444839583"^^xsd:double ;
//         oae:detectedAs       "permalink" ;
//         oae:position         "8401"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Permalink> .
//
//     _:e0-381 rdf:type oae:Entity ;
//         oae:confidence       "-2.49565039330669"^^xsd:double ;
//         oae:detectedAs       "php" ;
//         oae:position         "8411"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/PHP> .
//
//     _:e0-382 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8480"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-383 rdf:type oae:Entity ;
//         oae:confidence       "-4.705174260817093"^^xsd:double ;
//         oae:detectedAs       "id" ;
//         oae:position         "8442"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Id%2C_ego_and_super-ego> .
//
//     _:e0-384 rdf:type oae:Entity ;
//         oae:confidence       "-2.875843080958637"^^xsd:double ;
//         oae:detectedAs       "email" ;
//         oae:position         "8600"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Email> .
//
//     _:e0-385 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8568"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-386 rdf:type oae:Entity ;
//         oae:confidence       "-3.9453451660854197"^^xsd:double ;
//         oae:detectedAs       "tz" ;
//         oae:position         "8525"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/.tz> .
//
//     _:e0-387 rdf:type oae:Entity ;
//         oae:confidence       "-4.783635402056546"^^xsd:double ;
//         oae:detectedAs       "try" ;
//         oae:position         "8591"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Try> .
//
//     _:e0-388 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "8685"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-389 rdf:type oae:Entity ;
//         oae:confidence       "-2.675800756246614"^^xsd:double ;
//         oae:detectedAs       "focus" ;
//         oae:position         "8608"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Focus_%282015_film%29> .
//
//     _:e0-390 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8662"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-391 rdf:type oae:Entity ;
//         oae:confidence       "-1.1738489320961027"^^xsd:double ;
//         oae:detectedAs       "link data" ;
//         oae:position         "8756"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Linked_data> .
//
//     _:e0-392 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "8819"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-393 rdf:type oae:Entity ;
//         oae:confidence       "-3.068291223406482"^^xsd:double ;
//         oae:detectedAs       "js" ;
//         oae:position         "8726"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/JavaScript> .
//
//     _:e0-394 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8796"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-395 rdf:type oae:Entity ;
//         oae:confidence       "-3.895787545993451"^^xsd:double ;
//         oae:detectedAs       "ufi" ;
//         oae:position         "8744"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/UFI> .
//
//     _:e0-396 rdf:type oae:Entity ;
//         oae:confidence       "-3.895787545993451"^^xsd:double ;
//         oae:detectedAs       "ufi" ;
//         oae:position         "8713"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/UFI> .
//
//     _:e0-397 rdf:type oae:Entity ;
//         oae:confidence       "-1.666221798085479"^^xsd:double ;
//         oae:detectedAs       "bootloader" ;
//         oae:position         "8979"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Booting> .
//
//     _:e0-398 rdf:type oae:Entity ;
//         oae:confidence       "-3.8712007940373625"^^xsd:double ;
//         oae:detectedAs       "deprecated function" ;
//         oae:position         "8956"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Deprecation> .
//
//     _:e0-399 rdf:type oae:Entity ;
//         oae:confidence       "-1.7751764833303363"^^xsd:double ;
//         oae:detectedAs       "preload" ;
//         oae:position         "9048"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Preload_%28cardiology%29> .
//
//     _:e0-400 rdf:type oae:Entity ;
//         oae:confidence       "-1.7751764833303363"^^xsd:double ;
//         oae:detectedAs       "preload" ;
//         oae:position         "9016"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Preload_%28cardiology%29> .
//
//     _:e0-401 rdf:type oae:Entity ;
//         oae:confidence       "-3.36533387533944"^^xsd:double ;
//         oae:detectedAs       "link rel" ;
//         oae:position         "9039"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Canonical_link_element> .
//
//     _:e0-402 rdf:type oae:Entity ;
//         oae:confidence       "-3.36533387533944"^^xsd:double ;
//         oae:detectedAs       "link rel" ;
//         oae:position         "9007"^^xsd:integer ;
//         oae:hasMatchedURI    <http://dbpedia.org/resource/Canonical_link_element> .

// %% [markdown]
// # Sort and store with headers

// %%
val headers = TripleHeader.append("oae" -> "http://www.ics.forth.gr/isl/oae/core#")

// %%
val triples = ArchiveSpark2Triples.toStringsSorted(headers, documentTriples, sameAsTriples, versionTriples)
// Out:
// Unauthorized system.exit detected!

// %%
triples.saveAsTextFile(s"$collection-Triples1.gz", classOf[GzipCodec])
